# %% [markdown]
# # **MODELISATION OF CPUs**
#
# ### **GOAL :** Clean jupyter notebook for modelisation of CPUs and CPUs encapsulation materials

# %% [markdown]
# Imports and libraries

# %%
import pandas as pd
import requests
import os
from urllib.parse import urlparse
import camelot
import re
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from plotly.express import get_trendline_results

# %% [markdown]
# ### **Dataset :** MPU datasheets from STMicroelectronics and MPU datasheets from Infineon
#
# 1. LGA
#
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/0c/c1/60/5e/77/68/41/05/DM00013099/files/MD_O7%20SO%2008%20.15%20JEDEC_E7O7%20CPU016J.pdf/jcr:content/translations/en.MD_O7%20SO%2008%20.15%20JEDEC_E7O7%20CPU016J.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/18/9a/ee/7c/2e/72/4b/97/DM00825583/files/MD_A08N%20VFLGA2.5X3X.86%2014L%20P.5%20L.475X.25_22AA%20AU36ABC_vers2_signed.pdf/jcr:content/translations/en.MD_A08N%20VFLGA2.5X3X.86%2014L%20P.5%20L.475X.25_22AA%20AU36ABC_vers2_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/5d/8a/58/6b/86/12/48/d6/DM01104733/files/MD_A06R%20LGA%209.6X7.5%2018LD%20CERAMIC%20CAVITY_A2XZ%20AU23CDF_ver2-signed.pdf/jcr:content/translations/en.MD_A06R%20LGA%209.6X7.5%2018LD%20CERAMIC%20CAVITY_A2XZ%20AU23CDF_ver2-signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/98/a1/e0/01/27/36/4c/9c/DM01100634/files/MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf/jcr:content/translations/en.MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/e5/55/aa/da/5a/a3/40/33/DM00076551/files/MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf/jcr:content/translations/en.MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/e5/55/aa/da/5a/a3/40/33/DM00076551/files/MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf/jcr:content/translations/en.MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/9f/55/1f/91/15/47/47/88/DM00150211/files/MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf/jcr:content/translations/en.MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf
# https://www.infineon.com/row/public/documents/24/75/infineon-mcds-pasco2v15-ma006046957-materialcontentdatasheet-en.pdf
#
# 2. FCLGA
#
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/9f/55/1f/91/15/47/47/88/DM00150211/files/MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf/jcr:content/translations/en.MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf
#
# 3. BGA
#
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/98/a1/e0/01/27/36/4c/9c/DM01100634/files/MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf/jcr:content/translations/en.MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/e5/55/aa/da/5a/a3/40/33/DM00076551/files/MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf/jcr:content/translations/en.MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/2c/24/58/7c/0b/69/45/93/DM00089983/files/MD_A0SZ%20LGA%206.5X4X1%2028%20L%20PITCH%200.6%20MM_21DFMV0HCCB%20(LSM330DS)%20WCP%20ver2_signed.pdf/jcr:content/translations/en.MD_A0SZ%20LGA%206.5X4X1%2028%20L%20PITCH%200.6%20MM_21DFMV0HCCB%20(LSM330DS)%20WCP%20ver2_signed.pdf
# https://www.infineon.com/row/public/documents/10/71/infineon-ma001226480-materialcontentsheet-en.pdf
# https://www.infineon.com/row/public/documents/10/71/infineon-ma001426600-materialcontentsheet-en.pdf
#
# (C:\Users\Arthur Resilio\Desktop\Resilio\Coding\metaboli_cpu_gpu_data\PGA_BGA_BOM.ods)

# %% [markdown]
# Data Loading and cleaning

# %%
# load_dfs.py

# Folder containing Excel files
folder_path = r"C:\Users\Arthur Resilio\Desktop\Excel_cleaned"

# List all Excel files
all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(".xlsx")]

dfs = []

for file in all_files:
    try:
        df = pd.read_excel(file)

        # --- 1. Clean column names ---
        df.columns = (
            df.columns.astype(str)
            .str.strip()
            .str.replace('\n', ' ', regex=False)
            .str.replace('\r', '', regex=False)
            .str.replace('\xa0', ' ', regex=False)
        )

        # --- 2. Identify date columns (keep as datetime) ---
        date_columns = [col for col in df.columns if 'date' in col.lower()]
        for col in date_columns:
            try:
                df[col] = pd.to_datetime(df[col], errors='ignore')
            except:
                pass

        # --- 3. Convert mass/weight columns to numeric ---
        mass_columns = ['Mass [mg]', 'Weight [mg]', 'Mass\n[mg]', 'Weight\n[mg]']
        for col in mass_columns:
            if col in df.columns:
                df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

        dfs.append(df)

    except Exception as e:
        print(f"Error loading {file}: {e}")

print(f"✅ Total datasets successfully loaded: {len(dfs)}")

# Optionally save dfs to a pickle for use in the next script
pd.to_pickle(dfs, r"C:\Users\Arthur Resilio\Desktop\dfs_loaded.pkl")

# clean_dfs.py
# Load previously saved dfs
dfs = pd.read_pickle(r"C:\Users\Arthur Resilio\Desktop\dfs_loaded.pkl")

def clean_name(name):
    """Standardize text: lowercase, strip spaces, remove parentheses contents."""
    if not isinstance(name, str):
        return name
    name = name.strip()
    name = re.sub(r'\s+', ' ', name)  # collapse multiple spaces
    name = name.lower()
    name = re.sub(r'\s*\(.*?\)\s*', '', name)  # remove parentheses and contents
    return name

def compute_surface_from_first_two(size_series):
    """
    Compute surface using the first two valid numeric Size [mm] values for a given CPU.
    If only one value exists, assume square.
    """
    valid_sizes = pd.to_numeric(size_series, errors="coerce").dropna().values
    if len(valid_sizes) >= 2:
        return valid_sizes[0] * valid_sizes[1]
    elif len(valid_sizes) == 1:
        return valid_sizes[0] ** 2
    else:
        return None

def clean_bom_df(df):
    """
    Cleans a single CPU BOM DataFrame:
    - Forward fill CPU metadata (Name, Socket, Size, Date)
    - Standardize names and substances
    - Compute total mass and surface area per CPU
    """
    df = df.copy()

    # Forward fill CPU metadata
    for col in ['Name', 'Socket', 'Size [mm]', 'Date']:
        if col in df.columns:
            df[col] = df[col].ffill()

    # Standardize text columns
    for col in ['Homogeneous Material', 'Substances']:
        if col in df.columns:
            df[col] = df[col].apply(clean_name)

    # Convert mass column to numeric
    if 'Mass [mg]' in df.columns:
        df['Mass [mg]'] = pd.to_numeric(df['Mass [mg]'], errors='coerce').fillna(0)
    else:
        df['Mass [mg]'] = 0

    # ✅ Compute total CPU mass per Name
    df['CPU Total Mass [mg]'] = df.groupby('Name')['Mass [mg]'].transform('sum')

    # ✅ Compute surface per CPU from the first two valid size values
    df['Surface [mm²]'] = df.groupby('Name')['Size [mm]'].transform(compute_surface_from_first_two)

    return df

# Clean all DataFrames
dfs_high_level = [clean_bom_df(df) for df in dfs]

# Save cleaned DataFrames
output_path = r"C:\Users\Arthur Resilio\Desktop\dfs_cleaned.pkl"
pd.to_pickle(dfs_high_level, output_path)

print(f"Cleaned DataFrames saved with consistent total mass and 2-value-based surface computation → {output_path}")
# Out:
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# ✅ Total datasets successfully loaded: 10
# Cleaned DataFrames saved with consistent total mass and 2-value-based surface computation → C:\Users\Arthur Resilio\Desktop\dfs_cleaned.pkl
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\422749659.py:28: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')

# %%
print(dfs_high_level)
# Out:
# [            Name Socket  Size [mm]  Nb       Date Homogeneous Material  \
# 0   MA001226480     BGA       25.0 NaN 2019-10-16                  die
# 1   MA001226480     BGA       25.0 NaN 2019-10-16                 wire
# 2   MA001226480     BGA        1.0 NaN 2019-10-16        encapsulation
# 3   MA001226480     BGA        1.0 NaN 2019-10-16        encapsulation
# 4   MA001226480     BGA        1.0 NaN 2019-10-16        encapsulation
# 5   MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 6   MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 7   MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 8   MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 9   MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 10  MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 11  MA001226480     BGA        1.0 NaN 2019-10-16            substrate
# 12  MA001226480     BGA        1.0 NaN 2019-10-16              plating
# 13  MA001226480     BGA        1.0 NaN 2019-10-16              plating
# 14  MA001226480     BGA        1.0 NaN 2019-10-16           solderball
# 15  MA001226480     BGA        1.0 NaN 2019-10-16           solderball
# 16  MA001226480     BGA        1.0 NaN 2019-10-16        mold compound
# 17  MA001226480     BGA        1.0 NaN 2019-10-16        mold compound
#
#         Material Group                   Substances         CAS  Mass [mg]  \
# 0   inorganic material                      silicon   7440-21-3     49.517
# 1          noble metal                         gold   7440-57-5      9.468
# 2     organic material                 carbon black   1333-86-4      2.389
# 3             plastics                  epoxy resin           -    146.950
# 4   inorganic material               silicondioxide  60676-86-0   1045.379
# 5             plastics                  epoxy resin           -     24.545
# 6   inorganic material                bariumsulfate   7727-43-7     37.664
# 7             plastics                acrylic resin           -     43.589
# 8             plastics  bismaleimide triazine resin           -    146.953
# 9   inorganic material           aluminiumhydroxide  21645-51-2    161.648
# 10     non noble metal                       copper   7440-50-8    222.058
# 11  inorganic material                  glass fibre           -    279.210
# 12         noble metal                         gold   7440-57-5      0.001
# 13     non noble metal                       nickel   7440-02-0      0.002
# 14     non noble metal                         lead   7439-92-1    153.661
# 15     non noble metal                          tin   7440-31-5    261.638
# 16            plastics                  epoxy resin           -      1.743
# 17         noble metal                       silver   7440-22-4      5.230
#
#     Average Mass [%]  Sum [%]  Average Mass [ppm]  Sum [ppm]  \
# 0               1.91     1.91               19106    19106.0
# 1               0.37     0.37                3653     3653.0
# 2               0.09      NaN                 922        NaN
# 3               5.67      NaN               56702        NaN
# 4              40.33    46.09              403364   460988.0
# 5               0.95      NaN                9471        NaN
# 6               1.45      NaN               14533        NaN
# 7               1.68      NaN               16819        NaN
# 8               5.67      NaN               56702        NaN
# 9               6.24      NaN               62373        NaN
# 10              8.57      NaN               85682        NaN
# 11             10.77    35.33              107735   353315.0
# 12              0.00      NaN                   1        NaN
# 13              0.00     0.00                   1        2.0
# 14              5.93      NaN               59291        NaN
# 15             10.10    16.03              100954   160245.0
# 16              0.07      NaN                 673        NaN
# 17              0.20     0.27                2018     2691.0
#
#     CPU Total Mass [mg]  Surface [mm²] High Level Material
# 0              2591.645          625.0                 die
# 1              2591.645          625.0          connection
# 2              2591.645          625.0       encapsulation
# 3              2591.645          625.0       encapsulation
# 4              2591.645          625.0       encapsulation
# 5              2591.645          625.0             carrier
# 6              2591.645          625.0             carrier
# 7              2591.645          625.0             carrier
# 8              2591.645          625.0             carrier
# 9              2591.645          625.0             carrier
# 10             2591.645          625.0             carrier
# 11             2591.645          625.0             carrier
# 12             2591.645          625.0       encapsulation
# 13             2591.645          625.0       encapsulation
# 14             2591.645          625.0          connection
# 15             2591.645          625.0          connection
# 16             2591.645          625.0       encapsulation
# 17             2591.645          625.0       encapsulation  ,            Name Socket  Size [mm]  Nb       Date Homogeneous Material  \
# 0   MA001426600    BGA       27.0 NaN 2019-09-08                  die
# 1   MA001426600    BGA       27.0 NaN 2019-09-08                 wire
# 2   MA001426600    BGA        1.9 NaN 2019-09-08        encapsulation
# 3   MA001426600    BGA        1.9 NaN 2019-09-08        encapsulation
# 4   MA001426600    BGA        1.9 NaN 2019-09-08        encapsulation
# 5   MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 6   MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 7   MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 8   MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 9   MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 10  MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 11  MA001426600    BGA        1.9 NaN 2019-09-08            substrate
# 12  MA001426600    BGA        1.9 NaN 2019-09-08              plating
# 13  MA001426600    BGA        1.9 NaN 2019-09-08              plating
# 14  MA001426600    BGA        1.9 NaN 2019-09-08           solderball
# 15  MA001426600    BGA        1.9 NaN 2019-09-08           solderball
# 16  MA001426600    BGA        1.9 NaN 2019-09-08           solderball
# 17  MA001426600    BGA        1.9 NaN 2019-09-08                 glue
# 18  MA001426600    BGA        1.9 NaN 2019-09-08                 glue
#
#         Material Group                   Substances         CAS  Mass [mg]  \
# 0   inorganic material                      silicon   7440-21-3     54.869
# 1      non noble metal                       copper   7440-50-8      4.217
# 2     organic material                 carbon black   1333-86-4      2.380
# 3             plastics                  epoxy resin           -    146.346
# 4   inorganic material              silicon dioxide  60676-86-0   1041.077
# 5             plastics                  epoxy resin           -     22.546
# 6   inorganic material                bariumsulfate   7727-43-7     34.597
# 7             plastics                acrylic resin           -     40.039
# 8             plastics  bismaleimide triazine resin           -    122.239
# 9   inorganic material           aluminiumhydroxide  21645-51-2    134.463
# 10  inorganic material                  glass fibre           -    232.255
# 11     non noble metal                       copper   7440-50-8    961.301
# 12         noble metal                         gold   7440-57-5      2.345
# 13     non noble metal                       nickel   7440-02-0      6.419
# 14     non noble metal                       copper   7440-50-8      1.829
# 15         noble metal                       silver   7440-22-4     14.634
# 16     non noble metal                          tin   7440-31-5    349.395
# 17            plastics                  epoxy resin           -      1.884
# 18         noble metal                       silver   7440-22-4      5.652
#
#     Average Mass [%]  Sum [%]  Average Mass [ppm]  Sum [ppm]  \
# 0               1.73     1.73               17263    17263.0
# 1               0.13     0.13                1327     1327.0
# 2               0.07      NaN                 749        NaN
# 3               4.60      NaN               46042        NaN
# 4              32.76    37.43              327538   374329.0
# 5               0.71      NaN                7093        NaN
# 6               1.09      NaN               10885        NaN
# 7               1.26      NaN               12597        NaN
# 8               3.85      NaN               38458        NaN
# 9               4.23      NaN               42304        NaN
# 10              7.31      NaN               73071        NaN
# 11             30.24    48.69              302439   486847.0
# 12              0.07      NaN                 738        NaN
# 13              0.20     0.27                2020     2758.0
# 14              0.06      NaN                 576        NaN
# 15              0.46      NaN                4604        NaN
# 16             10.99    11.51              109925   115105.0
# 17              0.06      NaN                 593        NaN
# 18              0.18     0.24                1778     2371.0
#
#     CPU Total Mass [mg]  Surface [mm²] High Level Material
# 0              3178.487          729.0                 die
# 1              3178.487          729.0          connection
# 2              3178.487          729.0       encapsulation
# 3              3178.487          729.0       encapsulation
# 4              3178.487          729.0       encapsulation
# 5              3178.487          729.0             carrier
# 6              3178.487          729.0             carrier
# 7              3178.487          729.0             carrier
# 8              3178.487          729.0             carrier
# 9              3178.487          729.0             carrier
# 10             3178.487          729.0             carrier
# 11             3178.487          729.0             carrier
# 12             3178.487          729.0       encapsulation
# 13             3178.487          729.0       encapsulation
# 14             3178.487          729.0          connection
# 15             3178.487          729.0          connection
# 16             3178.487          729.0          connection
# 17             3178.487          729.0           finishing
# 18             3178.487          729.0           finishing  ,                      Name Socket  Size [mm]  Nb       Date  \
# 0   MA006046957*PASCO2V15    LGA       13.8 NaN 2024-07-04
# 1   MA006046957*PASCO2V15    LGA       14.0 NaN 2024-07-04
# 2   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 3   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 4   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 5   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 6   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 7   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 8   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 9   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 10  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 11  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 12  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 13  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 14  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 15  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 16  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 17  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 18  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 19  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 20  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 21  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 22  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 23  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 24  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 25  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 26  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 27  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 28  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 29  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 30  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 31  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 32  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 33  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
#
#    Homogeneous Material      Material Group                   Substances  \
# 0                chip_1  inorganic material                      silicon
# 1                chip_2  inorganic material                      silicon
# 2                  wire         noble metal                         gold
# 3         encapsulation  inorganic material               silicondioxide
# 4         encapsulation            plastics               silicone resin
# 5            leadfinish         noble metal                         gold
# 6            leadfinish     non noble metal                       nickel
# 7               plating         noble metal                         gold
# 8               plating     non noble metal                       nickel
# 9          solder paste     non noble metal                     antimony
# 10         solder paste     non noble metal                          tin
# 11                  lid     non noble metal                         zinc
# 12                  lid     non noble metal                       copper
# 13                 glue    organic material                 carbon black
# 14                 glue  inorganic material               silicondioxide
# 15                 glue    organic material                      oxirane
# 16                 glue    organic material            dimethyl siloxane
# 17                 glue            plastics                     silicone
# 18                 glue    organic material                dicyandiamide
# 19                 glue            plastics                  epoxy resin
# 20       solder resists    organic material          phthalocyanine blue
# 21       solder resists  inorganic material             amorphous silica
# 22       solder resists       miscellaneous                miscellaneous
# 23       solder resists  inorganic material   magnesiumsilicate hydrated
# 24       solder resists  inorganic material                bariumsulfate
# 25       solder resists            plastics                  cured resin
# 26      substrate metal     non noble metal                       copper
# 27    substrate plastic            plastics  bismaleimide triazine resin
# 28    substrate plastic  inorganic material           aluminiumhydroxide
# 29    substrate plastic  inorganic material                  glass fibre
# 30         lid platings         noble metal                         gold
# 31         lid platings  inorganic material                   phosphorus
# 32         lid platings     non noble metal                       nickel
# 33                                      NaN                          NaN
#
#            CAS  Mass [mg]  Average Mass [%]  Sum [%]  Average Mass [ppm]  \
# 0    7440-21-3      0.299             0.868    0.868              8679.0
# 1    7440-21-3      3.365             9.771    9.771             97712.0
# 2    7440-57-5      0.032             0.093    0.093               933.0
# 3   60676-86-0      0.036             0.104    1.042              1042.0
# 4            -      0.323             0.938      NaN              9379.0
# 5    7440-57-5      0.106             0.308    0.660              3081.0
# 6    7440-02-0      0.121             0.351      NaN              3514.0
# 7    7440-57-5      0.014             0.040    0.085               397.0
# 8    7440-02-0      0.016             0.045      NaN               452.0
# 9    7440-36-0      0.042             0.122    1.218              1218.0
# 10   7440-31-5      0.377             1.096      NaN             10962.0
# 11   7440-66-6      5.705            16.569   47.340            165690.0
# 12   7440-50-8     10.595            30.771      NaN            307710.0
# 13   1333-86-4      0.000             0.001    1.792                 7.0
# 14  60676-86-0      0.020             0.057      NaN               569.0
# 15   3101-60-8      0.028             0.082      NaN               824.0
# 16  67762-90-7      0.028             0.082      NaN               824.0
# 17           -      0.030             0.086      NaN               864.0
# 18    461-58-5      0.142             0.412      NaN              4120.0
# 19           -      0.369             1.071      NaN             10712.0
# 20    147-14-8      0.001             0.002    1.533                23.0
# 21   7631-86-9      0.005             0.014      NaN               138.0
# 22           -      0.012             0.036      NaN               360.0
# 23  14807-96-6      0.026             0.077      NaN               766.0
# 24   7727-43-7      0.158             0.460      NaN              4599.0
# 25           -      0.325             0.944      NaN              9443.0
# 26   7440-50-8      8.083            23.473   23.473            234732.0
# 27           -      0.834             2.423    9.691             24226.0
# 28  21645-51-2      0.918             2.665      NaN             26649.0
# 29           -      1.585             4.603      NaN             46030.0
# 30   7440-57-5      0.006             0.016    2.434               163.0
# 31   7723-14-0      0.297             0.864      NaN              8637.0
# 32   7440-02-0      0.535             1.554      NaN             15544.0
# 33         NaN      0.000               NaN      NaN                 NaN
#
#     Sum [ppm]  CPU Total Mass [mg]  Surface [mm²] High Level Material
# 0      8679.0               34.433          193.2                 die
# 1     97712.0               34.433          193.2                 die
# 2       933.0               34.433          193.2          connection
# 3     10421.0               34.433          193.2       encapsulation
# 4         NaN               34.433          193.2       encapsulation
# 5      6596.0               34.433          193.2             carrier
# 6         NaN               34.433          193.2             carrier
# 7       849.0               34.433          193.2       encapsulation
# 8         NaN               34.433          193.2       encapsulation
# 9     12180.0               34.433          193.2          connection
# 10        NaN               34.433          193.2          connection
# 11   473400.0               34.433          193.2       encapsulation
# 12        NaN               34.433          193.2       encapsulation
# 13    17920.0               34.433          193.2           finishing
# 14        NaN               34.433          193.2           finishing
# 15        NaN               34.433          193.2           finishing
# 16        NaN               34.433          193.2           finishing
# 17        NaN               34.433          193.2           finishing
# 18        NaN               34.433          193.2           finishing
# 19        NaN               34.433          193.2           finishing
# 20    15330.0               34.433          193.2          connection
# 21        NaN               34.433          193.2          connection
# 22        NaN               34.433          193.2          connection
# 23        NaN               34.433          193.2          connection
# 24        NaN               34.433          193.2          connection
# 25        NaN               34.433          193.2          connection
# 26   234732.0               34.433          193.2             carrier
# 27    96906.0               34.433          193.2             carrier
# 28        NaN               34.433          193.2             carrier
# 29        NaN               34.433          193.2             carrier
# 30    24344.0               34.433          193.2       encapsulation
# 31        NaN               34.433          193.2       encapsulation
# 32        NaN               34.433          193.2       encapsulation
# 33        NaN               34.433          193.2           finishing  ,                      Name Socket  Size [mm]  Nb       Date  \
# 0   MA006046957*PASCO2V15    LGA       13.8 NaN 2024-07-04
# 1   MA006046957*PASCO2V15    LGA       14.0 NaN 2024-07-04
# 2   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 3   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 4   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 5   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 6   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 7   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 8   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 9   MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 10  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 11  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 12  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 13  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 14  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 15  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 16  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 17  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 18  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 19  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 20  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 21  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 22  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 23  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
# 24  MA006046957*PASCO2V15    LGA        7.5 NaN 2024-07-04
#
#    Homogeneous Material      Material Group                   Substances  \
# 0                chip_1  inorganic material                      silicon
# 1                chip_2  inorganic material                      silicon
# 2                  wire         noble metal                         gold
# 3             finishing         noble metal                         gold
# 4             finishing     non noble metal                       nickel
# 5               plating       miscellaneous                miscellaneous
# 6               plating     non noble metal                       cobalt
# 7               plating         noble metal                         gold
# 8               plating     non noble metal                       nickel
# 9         mold compound       miscellaneous                miscellaneous
# 10        mold compound  inorganic material                 titandioxide
# 11        mold compound    organic material  dimer acid diglycidyl ester
# 12        mold compound    organic material                 carbon black
# 13        mold compound  inorganic material               silicondioxide
# 14        mold compound         noble metal                       silver
# 15        mold compound            plastics      polytetrafluoroethylene
# 16        mold compound            plastics                  epoxy resin
# 17            substrate     non noble metal                   molybdenum
# 18            substrate     non noble metal                     tungsten
# 19            substrate  inorganic material                 calciumoxide
# 20            substrate  inorganic material               magnesiumoxide
# 21            substrate  inorganic material                 titandioxide
# 22            substrate  inorganic material             amorphous silica
# 23            substrate  inorganic material                chromiumoxide
# 24            substrate  inorganic material                      alumina
#
#            CAS  Mass [mg]  Average Mass [%]  Sum [%]  Average Mass [ppm]  \
# 0    7440-21-3     20.147            26.286   26.286            262860.0
# 1    7440-21-3      1.598             2.085    2.085             20854.0
# 2    7440-57-5      0.035             0.045    0.045               452.0
# 3    7440-57-5      0.292             0.381    0.815              3808.0
# 4    7440-02-0      0.333             0.434      NaN              4343.0
# 5            -      0.000               NaN    0.266                 NaN
# 6    7440-48-4      0.034             0.044      NaN               441.0
# 7    7440-57-5      0.037             0.048      NaN               478.0
# 8    7440-02-0      0.134             0.174      NaN              1745.0
# 9            -      0.000             0.001    5.500                 5.0
# 10  13463-67-7      0.017             0.022      NaN               219.0
# 11  68475-94-5      0.101             0.131      NaN              1313.0
# 12   1333-86-4      0.151             0.197      NaN              1970.0
# 13  60676-86-0      0.412             0.537      NaN              5370.0
# 14   7440-22-4      0.574             0.749      NaN              7494.0
# 15   9002-84-0      1.107             1.445      NaN             14448.0
# 16           -      1.853             2.418      NaN             24177.0
# 17   7439-98-7      0.428             0.559   18.623              5587.0
# 18   7440-33-7     13.846            18.065      NaN            180647.0
# 19   1305-78-8      0.107             0.139   46.379              1391.0
# 20   1309-48-4      0.178             0.232      NaN              2319.0
# 21  13463-67-7      0.355             0.464      NaN              4638.0
# 22   7631-86-9      1.280             1.670      NaN             16696.0
# 23   1308-38-9      1.386             1.809      NaN             18088.0
# 24   1344-28-1     32.241            42.066      NaN            420656.0
#
#     Sum [ppm]  CPU Total Mass [mg]  Surface [mm²] High Level Material
# 0    262860.0               76.646          193.2                 die
# 1     20854.0               76.646          193.2                 die
# 2       452.0               76.646          193.2          connection
# 3      8151.0               76.646          193.2           finishing
# 4         NaN               76.646          193.2           finishing
# 5      2664.0               76.646          193.2       encapsulation
# 6         NaN               76.646          193.2       encapsulation
# 7         NaN               76.646          193.2       encapsulation
# 8         NaN               76.646          193.2       encapsulation
# 9     54996.0               76.646          193.2       encapsulation
# 10        NaN               76.646          193.2       encapsulation
# 11        NaN               76.646          193.2       encapsulation
# 12        NaN               76.646          193.2       encapsulation
# 13        NaN               76.646          193.2       encapsulation
# 14        NaN               76.646          193.2       encapsulation
# 15        NaN               76.646          193.2       encapsulation
# 16        NaN               76.646          193.2       encapsulation
# 17   186234.0               76.646          193.2             carrier
# 18        NaN               76.646          193.2             carrier
# 19   463789.0               76.646          193.2             carrier
# 20        NaN               76.646          193.2             carrier
# 21        NaN               76.646          193.2             carrier
# 22        NaN               76.646          193.2             carrier
# 23        NaN               76.646          193.2             carrier
# 24        NaN               76.646          193.2             carrier  ,             Name Socket  Size [mm]   Nb       Date Homogeneous Material  \
# 0   B50E*MT69AAA    BGA        3.0  4.0 2013-01-10                  die
# 1   B50E*MT69AAA    BGA        4.0  NaN 2013-01-10                  die
# 2   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                  die
# 3   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                  die
# 4   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                  die
# 5   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                  die
# 6   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                  die
# 7   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                  die
# 8   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 9   B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 10  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 11  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 12  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 13  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 14  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 15  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 16  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 17  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 18  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 19  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 20  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 21  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 22  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 23  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 24  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 25  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            substrate
# 26  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10           die attach
# 27  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10           die attach
# 28  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10           die attach
# 29  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10                 wire
# 30  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            underfill
# 31  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            underfill
# 32  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            underfill
# 33  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            underfill
# 34  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            underfill
# 35  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10            underfill
# 36  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 37  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 38  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 39  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 40  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 41  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 42  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 43  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 44  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 45  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10               cavity
# 46  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10         solder paste
# 47  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10         solder paste
# 48  B50E*MT69AAA    BGA     2001.0  NaN 2013-01-10         solder paste
#
#                Material Group  Component mass [mg]     Level  \
# 0   Other inorganic materials             8.025000  supplier
# 1                         NaN                  NaN  supplier
# 2                         NaN                  NaN  supplier
# 3                         NaN                  NaN  supplier
# 4                         NaN                  NaN  supplier
# 5                         NaN                  NaN  supplier
# 6                         NaN                  NaN  supplier
# 7                         NaN                  NaN  supplier
# 8     Other Organic Materials             7.289278  supplier
# 9                         NaN                  NaN  supplier
# 10                        NaN                  NaN  supplier
# 11                        NaN                  NaN  supplier
# 12                        NaN                  NaN  supplier
# 13                        NaN                  NaN  supplier
# 14                        NaN                  NaN  supplier
# 15                        NaN                  NaN  supplier
# 16                        NaN                  NaN  supplier
# 17                        NaN                  NaN  supplier
# 18                        NaN                  NaN  supplier
# 19                        NaN                  NaN  supplier
# 20                        NaN                  NaN  supplier
# 21                        NaN                  NaN  supplier
# 22                        NaN                  NaN  supplier
# 23                        NaN                  NaN  supplier
# 24                        NaN                  NaN  supplier
# 25                        NaN                  NaN  supplier
# 26    Other Organic Materials             0.682000  supplier
# 27                        NaN                  NaN  supplier
# 28                        NaN                  NaN  supplier
# 29             Precious metal             0.045000  supplier
# 30    Other Organic Materials             0.108000  supplier
# 31                        NaN                  NaN  supplier
# 32                        NaN                  NaN  supplier
# 33                        NaN                  NaN  supplier
# 34                        NaN                  NaN  supplier
# 35                        NaN                  NaN  supplier
# 36    Other Organic Materials            13.798000  supplier
# 37                        NaN                  NaN  supplier
# 38                        NaN                  NaN  supplier
# 39                        NaN                  NaN  supplier
# 40                        NaN                  NaN  supplier
# 41                        NaN                  NaN  supplier
# 42                        NaN                  NaN  supplier
# 43                        NaN                  NaN  supplier
# 44                        NaN                  NaN  supplier
# 45                        NaN                  NaN  supplier
# 46                     Solder             0.053000  supplier
# 47                        NaN                  NaN  supplier
# 48                        NaN                  NaN  supplier
#
#    Substance Category                                         Substances  \
# 0                 die                                            silicon
# 1       metallisation                                          aluminium
# 2       metallisation                                             copper
# 3       metallisation                                           tantalum
# 4       metallisation                                           titanium
# 5       metallisation                                               gold
# 6         passivation                                    silicon nitride
# 7         passivation                                      silicon oxide
# 8       core material                                        fiber glass
# 9       core material                       bisphenol f type epoxy resin
# 10      core material                                    metal hydroxide
# 11      core material                                     zinc hydroxyde
# 12      core material                                    calcium sulfate
# 13      core material                                       bismaleimide
# 14      core material                                           triazine
# 15        Solder mask                                           propanol
# 16        Solder mask              talc containing no asbestiform fibers
# 17        Solder mask                                             quartz
# 18        Solder mask                                    2-ethyl acetate
# 19        Solder mask                                        epoxy resin
# 20        Solder mask                               aromatic hydrocarbon
# 21        Solder mask                                     amine compound
# 22      metallisation                                             copper
# 23      metallisation                                             nickel
# 24      metallisation                                               gold
# 25      metallisation                                          palladium
# 26       glue or tape        dimethyl siloxane, dimethylvinyl-terminated
# 27       glue or tape                               trimethylated silica
# 28       glue or tape  dimethyl, methylhydrogen siloxane, hydrogen-te...
# 29               wire                                               gold
# 30              resin                                   amorphous silica
# 31              resin                       bisphenol f type epoxy resin
# 32              resin                  4,4'-ethylidenediphenyl dicyanate
# 33              resin                                     aromatic amine
# 34              resin                2,6-diglycidylphenyl glycidyl ether
# 35              resin                                           butanone
# 36      core material                                       bismaleimide
# 37      core material                                           triazine
# 38      core material                                        fiber glass
# 39      core material                                    metal hydroxide
# 40      core material                                     zinc hydroxide
# 41      core material                                thermosetting resin
# 42      core material                                    calcium sulfate
# 43      metallisation                                             nickel
# 44      metallisation                                               gold
# 45      metallisation                                          palladium
# 46             Solder                                                tin
# 47             Solder                                           antimony
# 48             Solder                                          colophony
#
#              CAS  Mass [mg]  Concentration  in  homogeneous  material (ppm)  \
# 0      7440-21-3   7.946000                                          990156
# 1      7429-90-5   0.003000                                             374
# 2      7440-50-8   0.014000                                            1745
# 3      7440-25-7   0.002000                                             249
# 4      7440-32-6   0.001000                                             125
# 5      7440-57-5   0.042000                                            5234
# 6     68034-42-4   0.004000                                             498
# 7      7631-86-9   0.013000                                            1620
# 8     65997-17-3   2.429000                                          333229
# 9      9003-36-5   1.352000                                          185478
# 10    21645-51-2   0.055000                                            7545
# 11    20427-58-1   0.011000                                            1509
# 12     7778-18-9   0.028000                                            3841
# 13   105391-33-1   0.822000                                          112768
# 14    25722-66-1   0.822000                                          112768
# 15    34590-94-8   0.068000                                            9329
# 16    14807-96-6   0.011000                                            1509
# 17    14808-60-7   0.038000                                            5213
# 18      112-15-2   0.038000                                            5213
# 19    29690-82-2   0.157000                                           21538
# 20            na   0.052000                                            7134
# 21            na   0.015000                                            2058
# 22     7440-50-8   1.111000                                          152416
# 23     7440-02-0   0.176400                                           24200
# 24     7440-57-5   0.057000                                            7820
# 25     7440-05-3   0.046878                                            6431
# 26    68083-19-2   0.607000                                          890029
# 27    68909-20-6   0.055000                                           80645
# 28           NaN   0.020000                                           29326
# 29     7440-57-5   0.045000                                         1000000
# 30     7631-86-9   0.058000                                          537037
# 31     9003-36-5   0.030000                                          277778
# 32  EC 405-740-1   0.008000                                           74074
# 33   Proprietary   0.003000                                           27778
# 34    13561-08-5   0.008000                                           74074
# 35       78-93-3   0.001000                                            9259
# 36   105391-33-1   2.034000                                          147413
# 37    25722-66-1   2.034000                                          147413
# 38    65997-17-3   6.067000                                          439701
# 39    21645-51-2   0.138000                                           10001
# 40    20427-58-1   0.042000                                            3044
# 41    54208-63-8   3.405000                                          246775
# 42     7778-18-9   0.069000                                            5001
# 43     7440-02-0   0.007000                                             507
# 44     7440-57-5   0.001000                                              72
# 45     7440-05-3   0.001000                                              72
# 46     7440-31-5   0.047000                                          886792
# 47     7440-36-0   0.005000                                           94340
# 48     8050-09-7   0.001000                                           18868
#
#     Concentration  in  product (ppm)  CPU Total Mass [mg]  Surface [mm²]  \
# 0                             264867            30.000278           12.0
# 1                                100            30.000278           12.0
# 2                                467            30.000278           12.0
# 3                                 67            30.000278           12.0
# 4                                 33            30.000278           12.0
# 5                               1400            30.000278           12.0
# 6                                133            30.000278           12.0
# 7                                433            30.000278           12.0
# 8                              80967            30.000278           12.0
# 9                              45067            30.000278           12.0
# 10                              1833            30.000278           12.0
# 11                               367            30.000278           12.0
# 12                               933            30.000278           12.0
# 13                             27400            30.000278           12.0
# 14                             27400            30.000278           12.0
# 15                              2267            30.000278           12.0
# 16                               367            30.000278           12.0
# 17                              1267            30.000278           12.0
# 18                              1267            30.000278           12.0
# 19                              5233            30.000278           12.0
# 20                              1733            30.000278           12.0
# 21                               500            30.000278           12.0
# 22                             37033            30.000278           12.0
# 23                              5880            30.000278           12.0
# 24                              1900            30.000278           12.0
# 25                              1563            30.000278           12.0
# 26                             20233            30.000278           12.0
# 27                              1833            30.000278           12.0
# 28                               667            30.000278           12.0
# 29                              1500            30.000278           12.0
# 30                              1933            30.000278           12.0
# 31                              1000            30.000278           12.0
# 32                               267            30.000278           12.0
# 33                               100            30.000278           12.0
# 34                               267            30.000278           12.0
# 35                                33            30.000278           12.0
# 36                             67800            30.000278           12.0
# 37                             67800            30.000278           12.0
# 38                            202233            30.000278           12.0
# 39                              4600            30.000278           12.0
# 40                              1400            30.000278           12.0
# 41                            113500            30.000278           12.0
# 42                              2300            30.000278           12.0
# 43                               233            30.000278           12.0
# 44                                33            30.000278           12.0
# 45                                33            30.000278           12.0
# 46                              1567            30.000278           12.0
# 47                               167            30.000278           12.0
# 48                                33            30.000278           12.0
#
#    High Level Material
# 0                  die
# 1                  die
# 2                  die
# 3                  die
# 4                  die
# 5                  die
# 6                  die
# 7                  die
# 8              carrier
# 9              carrier
# 10             carrier
# 11             carrier
# 12             carrier
# 13             carrier
# 14             carrier
# 15             carrier
# 16             carrier
# 17             carrier
# 18             carrier
# 19             carrier
# 20             carrier
# 21             carrier
# 22             carrier
# 23             carrier
# 24             carrier
# 25             carrier
# 26                 die
# 27                 die
# 28                 die
# 29          connection
# 30          connection
# 31          connection
# 32          connection
# 33          connection
# 34          connection
# 35          connection
# 36             carrier
# 37             carrier
# 38             carrier
# 39             carrier
# 40             carrier
# 41             carrier
# 42             carrier
# 43             carrier
# 44             carrier
# 45             carrier
# 46          connection
# 47          connection
# ...
# 17   21645-51-2      0.462                                           68811
# 18  Proprietary      0.462                                           68811
# 19  Proprietary      0.867                                          129133
# 20    7727-43-7      0.438                                           65239
# 21   14807-96-6      0.051                                            7596
# 22     147-14-8      0.003                                             447
# 23    7631-86-9      0.013                                            1936
# 24  Proprietary      0.003                                             447
# 25  Proprietary      0.034                                            5064
# 26    7440-50-8      1.598                                          238010
# 27    7440-02-0      0.285                                           42449
# 28    7440-57-5      0.062                                            9234
# 29   60676-86-0     11.417                                          884970
# 30  Proprietary      0.516                                           39997
# 31  Proprietary      0.387                                           29998
# 32    1333-86-4      0.065                                            5038
# 33  Proprietary      0.387                                           29998
# 34  Proprietary      0.129                                            9999
# 35    7440-50-8      0.014                                          170732
# 36    7440-31-5      0.066                                          804878
# 37    7440-22-4      0.002                                           24390
# 38    5026-74-4      0.033                                          100000
# 39    9003-36-5      0.033                                          100000
# 40   25068-38-6      0.013                                           39394
# 41  Proprietary      0.023                                           69697
# 42   60676-86-0      0.215                                          651515
# 43    1333-86-4      0.003                                            9091
# 44  Proprietary      0.007                                           21212
# 45  Proprietary      0.003                                            9091
# 46    7440-50-8      1.200                                          747663
# 47    7440-02-0      0.333                                          207477
# 48    7440-57-5      0.072                                           44860
#
#     Concentration  in  product (ppm)  CPU Total Mass [mg]  Surface [mm²]  \
# 0                              27221               29.389           16.0
# 1                                102               29.389           16.0
# 2                               2076               29.389           16.0
# 3                                102               29.389           16.0
# 4                                 34               29.389           16.0
# 5                                238               29.389           16.0
# 6                               2076               29.389           16.0
# 7                                612               29.389           16.0
# 8                                408               29.389           16.0
# 9                                817               29.389           16.0
# 10                                34               29.389           16.0
# 11                            220012               29.389           16.0
# 12                             10207               29.389           16.0
# 13                             51447               29.389           16.0
# 14                             10480               29.389           16.0
# 15                             10480               29.389           16.0
# 16                             10480               29.389           16.0
# 17                             15720               29.389           16.0
# 18                             15720               29.389           16.0
# 19                             29512               29.389           16.0
# 20                             14904               29.389           16.0
# 21                              1735               29.389           16.0
# 22                               102               29.389           16.0
# 23                               442               29.389           16.0
# 24                               102               29.389           16.0
# 25                              1157               29.389           16.0
# 26                             54373               29.389           16.0
# 27                              9698               29.389           16.0
# 28                              2110               29.389           16.0
# 29                            388476               29.389           16.0
# 30                             17558               29.389           16.0
# 31                             13167               29.389           16.0
# 32                              2212               29.389           16.0
# 33                             13167               29.389           16.0
# 34                              4389               29.389           16.0
# 35                               476               29.389           16.0
# 36                              2246               29.389           16.0
# 37                                68               29.389           16.0
# 38                              1123               29.389           16.0
# 39                              1123               29.389           16.0
# 40                               442               29.389           16.0
# 41                               783               29.389           16.0
# 42                              7316               29.389           16.0
# 43                               102               29.389           16.0
# 44                               238               29.389           16.0
# 45                               102               29.389           16.0
# 46                             40830               29.389           16.0
# 47                             11331               29.389           16.0
# 48                              2450               29.389           16.0
#
#    High Level Material
# 0                  die
# 1                  die
# 2                  die
# 3                  die
# 4                  die
# 5                  die
# 6                  die
# 7                  die
# 8                  die
# 9                  die
# 10                 die
# 11                 die
# 12                 die
# 13             carrier
# 14             carrier
# 15             carrier
# 16             carrier
# 17             carrier
# 18             carrier
# 19             carrier
# 20             carrier
# 21             carrier
# 22             carrier
# 23             carrier
# 24             carrier
# 25             carrier
# 26             carrier
# 27             carrier
# 28             carrier
# 29       encapsulation
# 30       encapsulation
# 31       encapsulation
# 32       encapsulation
# 33       encapsulation
# 34       encapsulation
# 35          connection
# 36          connection
# 37          connection
# 38          connection
# 39          connection
# 40          connection
# 41          connection
# 42          connection
# 43          connection
# 44          connection
# 45          connection
# 46           finishing
# 47           finishing
# 48           finishing  ,               Name Socket  Size [mm]  Nb       Date Homogeneous Material  \
# 0   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18                  die
# 1   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18                  die
# 2   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18                  die
# 3   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18                  die
# 4   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18                  die
# 5   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18            leadframe
# 6   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18            leadframe
# 7   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18            leadframe
# 8   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18            leadframe
# 9   I E7O7*CPU016J    NAN        NaN NaN 2010-05-18    leadframe coating
# 10  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18    leadframe coating
# 11  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18    leadframe coating
# 12  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18           die attach
# 13  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18           die attach
# 14  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18           die attach
# 15  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18                 wire
# 16  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18        mold compound
# 17  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18        mold compound
# 18  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18        mold compound
# 19  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18        mold compound
# 20  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18        mold compound
# 21  I E7O7*CPU016J    NAN        NaN NaN 2010-05-18        mold compound
#
#     Material Group  Component mass [mg]    Substance Category  \
# 0              NaN                1.943           Silicon die
# 1              NaN                  NaN     Die metallization
# 2              NaN                  NaN     Die metallization
# 3              NaN                  NaN     Die metallization
# 4              NaN                  NaN     Die metallization
# 5              NaN               28.887                 Alloy
# 6              NaN                  NaN                 Alloy
# 7              NaN                  NaN                 Alloy
# 8              NaN                  NaN                 Alloy
# 9              NaN                0.162               Coating
# 10             NaN                  NaN               Coating
# 11             NaN                  NaN               Coating
# 12             NaN                1.027    Lead/Lead Compound
# 13             NaN                  NaN          soft soldier
# 14             NaN                  NaN          soft soldier
# 15             NaN                0.962          Bonding wire
# 16             NaN               47.019     Moulding compounf
# 17             NaN                  NaN     Moulding compounf
# 18             NaN                  NaN     Moulding compounf
# 19             NaN                  NaN     Moulding compounf
# 20             NaN                  NaN   Antimony/Antimony C
# 21             NaN                  NaN  Brominated Flame Ret
#
#                 Substances           CAS  Mass [mg]  \
# 0                  silicon     7440-21-3      1.908
# 1                aluminium     7429-90-5      0.013
# 2                 titanium     7440-32-6      0.001
# 3                   nickel     7440-02-0      0.017
# 4                     gold     7440-57-5      0.004
# 5                   copper     7440-50-8     28.150
# 6                     iron     7439-89-6      0.678
# 7                     zinc     7440-66-6      0.035
# 8           iron phosphide    26508-33-8      0.024
# 9                   nickel     7440-02-0      0.148
# 10               palladium     7440-05-3      0.010
# 11                    gold     7440-57-5      0.004
# 12                    lead     7439-92-1      0.000
# 13                  silver     7440-22-4      0.026
# 14                     tin   7440-31-5\n      0.051
# 15                    gold     7440-57-5      0.962
# 16    epoxy cresol novolak    29690-82-2      4.702
# 17            phenol resin     9003-35-4      2.351
# 18            carbon black     1333-86-4      0.470
# 19        silica, vitreous  60676-86-0\n     37.616
# 20       antimony trioxide     1309-64-4      0.940
# 21  brominated epoxy resin    98928-70-1      0.940
#
#     Concentration  in  homogeneous  material (ppm)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
#
#     Concentration  in  product (ppm)     Unnamed: 14  CPU Total Mass [mg]  \
# 0                                NaN             NaN                79.05
# 1                                NaN             NaN                79.05
# 2                                NaN             515                79.05
# 3                                NaN           8,749                79.05
# 4                                NaN           2,059                79.05
# 5                                NaN          974,48                79.05
# 6                                NaN          23,471                79.05
# 7                                NaN           1,212                79.05
# 8                                NaN             831                79.05
# 9                                NaN          913,58                79.05
# 10                               NaN          61,728                79.05
# 11                               NaN          24,691                79.05
# 12                               NaN          925,02                79.05
# 13                               NaN          25,316                79.05
# 14                               NaN          49,659                79.05
# 15                               NaN             NaN                79.05
# 16                               NaN          100,00                79.05
# 17                               NaN          50,001                79.05
# 18                               NaN           9,996                79.05
# 19                               NaN  800,01\n19,992                79.05
# 20                               NaN             NaN                79.05
# 21                               NaN          19,992                79.05
#
#     Surface [mm²] High Level Material
# 0             NaN                 die
# 1             NaN                 die
# 2             NaN                 die
# 3             NaN                 die
# 4             NaN                 die
# 5             NaN             carrier
# 6             NaN             carrier
# 7             NaN             carrier
# 8             NaN             carrier
# 9             NaN             carrier
# 10            NaN             carrier
# 11            NaN             carrier
# 12            NaN                 die
# 13            NaN                 die
# 14            NaN                 die
# 15            NaN          connection
# 16            NaN       encapsulation
# 17            NaN       encapsulation
# 18            NaN       encapsulation
# 19            NaN       encapsulation
# 20            NaN       encapsulation
# 21            NaN       encapsulation  ]

# %% [markdown]
# Definition of high_level material categories, and surface and weight total

# %%
hm_set = set()
for df in dfs_high_level:
    if 'Homogeneous Material' in df.columns:
        hm_set.update(df['Homogeneous Material'].astype(str).str.strip().str.lower())

# Convert to sorted list
all_hm = sorted(hm_set)

# --- Initialize sets ---
hm_lga = set()
hm_bga = set()

# --- Iterate through each dataframe ---
for df in dfs_high_level:
    if 'Homogeneous Material' in df.columns and 'Socket' in df.columns:
        # Clean strings
        df["Homogeneous Material"] = df["Homogeneous Material"].astype(str).str.strip().str.lower()
        df["Socket"] = df["Socket"].astype(str).str.strip().str.upper()

        # Separate by socket type
        hm_lga.update(df.loc[df["Socket"] == "LGA", "Homogeneous Material"])
        hm_bga.update(df.loc[df["Socket"] == "BGA", "Homogeneous Material"])

# --- Convert to sorted lists ---
hm_lga = sorted(hm_lga)
hm_bga = sorted(hm_bga)

# --- Print results ---
print("Homogeneous Materials for LGA CPUs:")
print(", ".join(hm_lga))
print("\nHomogeneous Materials for BGA CPUs:")
print(", ".join(hm_bga))

def group_homogeneous_material(dfs_cleaned):
    # Define mapping groups
    hm_mapping = {
        'die': ['chip_1', 'chip_2', 'die', 'die attach'],
        'carrier': ['cavity', 'leadfinish', 'leadframe', 'leadframe coating', 'substrate', 'substrate metal', 'substrate plastic',],
        'encapsulation': ['encapsulation', 'lid', 'lid platings', 'metal lid', 'mold compound', 'plating'],
        'connection': ['bump', 'wire', 'underfill', 'solder paste', 'solder resists', 'solderball','underfill'],
        'finishing': ['finishing', 'glue', 'coating', '']
    }

    # Create a flat mapping dictionary (value -> high level group)
    material_to_group = {}
    for group, materials in hm_mapping.items():
        for material in materials:
            material_to_group[material] = group

    dfs_high_level = []

    for df in dfs_cleaned:
        df_copy = df.copy()

        # Clean and map homogeneous material to high level group
        df_copy['High Level Material'] = (
            df_copy['Homogeneous Material']
            .astype(str).str.lower().str.strip()
            .map(material_to_group)  # Map to high level
            .fillna('other')  # For anything not in mapping
        )

        dfs_high_level.append(df_copy)

    return dfs_high_level
# Out:
# Homogeneous Materials for LGA CPUs:
# , bump, chip_1, chip_2, coating, die, die attach, encapsulation, finishing, glue, leadfinish, lid, lid platings, metal lid, mold compound, plating, solder paste, solder resists, substrate, substrate metal, substrate plastic, underfill, wire
#
# Homogeneous Materials for BGA CPUs:
# cavity, die, die attach, encapsulation, glue, mold compound, plating, solder paste, solderball, substrate, underfill, wire

# %%
dfs_high_level = group_homogeneous_material(dfs_high_level)
dfs_high_level[8].head()
# Out:
#            Name Socket  Size [mm]    Nb       Date Homogeneous Material  \
# 0  SAVT*WRAVAA4    LGA        4.0  24.0 2014-11-25                  die
# 1  SAVT*WRAVAA4    LGA        4.0   NaN 2014-11-25                  die
# 2  SAVT*WRAVAA4    LGA        0.8   NaN 2014-11-25                  die
# 3  SAVT*WRAVAA4    LGA        0.8   NaN 2014-11-25                  die
# 4  SAVT*WRAVAA4    LGA        0.8   NaN 2014-11-25                  die
#
#               Material Group  Component mass [mg]     Level  \
# 0  Other inorganic materials                7.757  supplier
# 1                        NaN                  NaN  supplier
# 2                        NaN                  NaN  supplier
# 3                        NaN                  NaN  supplier
# 4                        NaN                  NaN  supplier
#
#   Substance Category Substances        CAS  Mass [mg]  \
# 0                die    silicon  7440-21-3      0.800
# 1      metallisation  aluminium  7429-90-5      0.003
# 2      metallisation     copper  7440-50-8      0.061
# 3      metallisation   tantalum  7440-25-7      0.003
# 4      metallisation   titanium  7440-32-6      0.001
#
#    Concentration  in  homogeneous  material (ppm)  \
# 0                                          103133
# 1                                             387
# 2                                            7864
# 3                                             387
# 4                                             129
#
#    Concentration  in  product (ppm)  CPU Total Mass [mg]  Surface [mm²]  \
# 0                             27221               29.389           16.0
# 1                               102               29.389           16.0
# 2                              2076               29.389           16.0
# 3                               102               29.389           16.0
# 4                                34               29.389           16.0
#
#   High Level Material
# 0                 die
# 1                 die
# 2                 die
# 3                 die
# 4                 die

# %% [markdown]
# ## **Parametric modelisation**
#
# ### **GOAL :** Create a parametric CPU model for the materials for various types of CPUs
#
# - Socket type
# - High level / homogeneous materials
# - Surface
# - Total Mass

# %%
def plot_cpu_category_relation(
    df_list,
    category,
    category_level='high',       # 'high' or 'homogeneous'
    socket_type='all',           # 'BGA', 'LGA', or 'all'
    y_value_type='mass',         # 'mass' or 'percentage'
    x_axis='mass'                # 'mass' or 'surface'
):
    """
    Plots CPU-level relationship between total mass/surface and mass (or %) of a given material category.
    Each point = one CPU. The y-axis value is the SUM of all substance masses in the chosen category for that CPU.
    Also returns the trendline formula if available.
    """

    # Combine all datasets
    df = pd.concat(df_list, ignore_index=True)

    # Optional: filter socket
    if socket_type.lower() != 'all':
        df = df[df['Socket'].str.lower() == socket_type.lower()]

    # Choose the right category column
    cat_col = 'High Level Material' if category_level == 'high' else 'Homogeneous Material'
    if cat_col not in df.columns:
        raise ValueError(f"Column '{cat_col}' not found in the DataFrame.")

    # Drop missing category rows
    df = df.dropna(subset=[cat_col, 'Mass [mg]', 'CPU Total Mass [mg]'])

    # --- STEP 1: aggregate substance mass per CPU × category ---
    cat_mass = (
        df.groupby(['Name', cat_col], as_index=False)['Mass [mg]']
        .sum()
        .rename(columns={'Mass [mg]': 'Category Mass [mg]'})
    )

    # --- STEP 2: total CPU mass & surface ---
    cpu_totals = (
        df.groupby('Name', as_index=False)[['CPU Total Mass [mg]', 'Surface [mm²]']]
        .mean()
    )

    # --- STEP 3: merge totals ---
    merged = pd.merge(cat_mass, cpu_totals, on='Name', how='left')

    # --- STEP 4: filter the chosen category ---
    subset = merged[merged[cat_col].str.lower() == category.lower()]
    if subset.empty:
        raise ValueError(f"No data found for category '{category}' at level '{category_level}'.")

    # --- STEP 5: compute y-value ---
    if y_value_type == 'percentage':
        subset['Category Value'] = subset['Category Mass [mg]'] / subset['CPU Total Mass [mg]'] * 100
        y_label = f"{category.capitalize()} mass [% of CPU]"
    else:
        subset['Category Value'] = subset['Category Mass [mg]']
        y_label = f"{category.capitalize()} mass [mg]"

    # --- STEP 6: choose x-axis variable ---
    if x_axis == 'mass':
        x_col, x_label = 'CPU Total Mass [mg]', 'CPU Total Mass [mg]'
    elif x_axis == 'surface':
        x_col, x_label = 'Surface [mm²]', 'CPU Surface [mm²]'
    else:
        raise ValueError("x_axis must be 'mass' or 'surface'.")

    # --- STEP 7: plot interactive scatter with trendline ---
    fig = px.scatter(
        subset,
        x=x_col,
        y='Category Value',
        hover_name='Name',
        title=f"{category.capitalize()} vs CPU {x_axis.capitalize()} ({y_value_type})",
        labels={'Category Value': y_label, x_col: x_label},
        color=x_col,
        color_continuous_scale='Viridis',
        trendline='ols'
    )

    # Extract trendline formula
    results = get_trendline_results(fig)
    formula = None

    if not results.empty:
        model = results.iloc[0]["px_fit_results"]
        params = model.params

        # Case 1: statsmodels Series with named params
        if hasattr(params, "index"):
            intercept = params.get("Intercept", params.iloc[0])
            slope_candidates = [k for k in params.index if k != "Intercept"]
            slope = params[slope_candidates[0]] if slope_candidates else params.iloc[1]
        # Case 2: plain NumPy array (no names)
        elif isinstance(params, (list, tuple)) or hasattr(params, "__len__"):
            intercept = params[0]
            slope = params[1] if len(params) > 1 else 0
        else:
            intercept, slope = None, None

        # Try to get R² if available
        r2 = getattr(model, "rsquared", None)
        if r2 is not None:
            formula = f"{y_label} = {intercept:.3f} + {slope:.3f} × {x_label}  (R² = {r2:.3f})"
        else:
            formula = f"{y_label} = {intercept:.3f} + {slope:.3f} × {x_label}"

    # Update figure layout
    fig.update_traces(marker=dict(size=10, opacity=0.8))
    fig.update_layout(height=600, margin=dict(l=80, r=60, t=80, b=60))

    # Show the figure
    fig.show()

    return fig, formula

# %%
plot_cpu_category_relation(
    dfs_high_level,
    category='carrier',
    category_level='high',
    socket_type='LGA',
    y_value_type='mass',
    x_axis='surface'
)
# Out:
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_28004\160527425.py:56: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (Figure({
#      'data': [{'hovertemplate': ('<b>%{hovertext}</b><br><br>CPU' ... ' mass [mg]=%{y}<extra></extra>'),
#                'hovertext': array(['A2XZ*AU23CDF ', 'D53N*MT78ADA ', 'MA006046957*PASCO2V15',
#                                    'SAVT*WRAVAA4'], dtype=object),
#                'legendgroup': '',
#                'marker': {'color': {'bdata': 'AAAAAAAAUkAAAAAAAAAiQGdmZmZmJmhAAAAAAAAAMEA=', 'dtype': 'f8'},
#                           'coloraxis': 'coloraxis',
#                           'opacity': 0.8,
#                           'size': 10,
#                           'symbol': 'circle'},
#                'mode': 'markers',
#                'name': '',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AAAAAAAAUkAAAAAAAAAiQGdmZmZmJmhAAAAAAAAAMEA=', 'dtype': 'f8'},
#                'xaxis': 'x',
#                'y': {'bdata': 'Urgehes5b0DJdr6fGi8FQJZDi2znu05AQmDl0CLbGkA=', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'hovertemplate': ('<b>OLS trendline</b><br>Catego' ... ' <b>(trend)</b><extra></extra>'),
#                'legendgroup': '',
#                'marker': {'opacity': 0.8, 'size': 10, 'symbol': 'circle'},
#                'mode': 'lines',
#                'name': '',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AAAAAAAAIkAAAAAAAAAwQAAAAAAAAFJAZ2ZmZmYmaEA=', 'dtype': 'f8'},
#                'xaxis': 'x',
#                'y': {'bdata': 'kS08ETNETkBMjYUH7VhPQJJF6Fxe/1NALjlGWQdbXUA=', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'coloraxis': {'colorbar': {'title': {'text': 'CPU Surface [mm²]'}},
#                               'colorscale': [[0.0, '#440154'], [0.1111111111111111,
#                                              '#482878'], [0.2222222222222222,
#                                              '#3e4989'], [0.3333333333333333,
#                                              '#31688e'], [0.4444444444444444,
#                                              '#26828e'], [0.5555555555555556,
#                                              '#1f9e89'], [0.6666666666666666,
#                                              '#35b779'], [0.7777777777777778,
#                                              '#6ece58'], [0.8888888888888888,
#                                              '#b5de2b'], [1.0, '#fde725']]},
#                 'height': 600,
#                 'legend': {'tracegroupgap': 0},
#                 'margin': {'b': 60, 'l': 80, 'r': 60, 't': 80},
#                 'template': '...',
#                 'title': {'text': 'Carrier vs CPU Surface (mass)'},
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'CPU Surface [mm²]'}},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Carrier mass [mg]'}}}
#  }),
#  'Carrier mass [mg] = 57.753 + 0.309 × CPU Surface [mm²]  (R² = 0.051)')

# %% [markdown]
# The only high level category for which we have enough points of data to fit a regression is the carrier

# %% [markdown]
# ## **Model**
#
# Parameters in TechPowerUp: size, weight, socket, technology

# %%
def build_model_cpu(dfs_high_level, technologie="flip chip", socket="LGA",
                    surface_mm2=100.0, weight_mg=200.0, yield_pct=95.0):
    """
    Build CPU material model:
    - die/carrier/encapsulation/finishing: keep all from specified socket
    - connection: filter by technology allowed list
    - Scale carrier by surface, all materials by CPU weight
    - Adjust for yield
    """

    # Combine all input dataframes
    df = pd.concat(dfs_high_level, ignore_index=True)
    
    # Clean column names (strip spaces and newlines)
    df.columns = df.columns.str.strip().str.replace('\n','')
    
    socket = socket.upper()
    if socket not in ["LGA","BGA"]:
        raise ValueError("Socket must be 'LGA' or 'BGA'")
    if 'Socket' not in df.columns:
        raise ValueError("Input data must have 'Socket' column")
    if 'High Level Material' not in df.columns:
        raise ValueError("Input data must have 'High Level Material' column")
    if 'Homogeneous Material' not in df.columns:
        raise ValueError("Input data must have 'Homogeneous Material' column")
    if 'Mass [mg]' not in df.columns:
        raise ValueError("Input data must have 'Mass [mg]' column")

    # Keep only CPUs with the specified socket
    df = df[df['Socket'].str.upper() == socket].copy()
    if df.empty:
        raise ValueError(f"No CPUs with socket {socket} found")

    # Clean Homogeneous Material values
    df['Homogeneous Material'] = df['Homogeneous Material'].str.strip().str.lower()

    # Allowed homogeneous materials by technology
    tech_mats = {
        "flip chip": {"underfill","lid","lid platings","metal lid","bump","plating"},
        "wire bonding": {"wire","die","die attach","mold compound","encapsulation"}
    }
    tech_allowed = tech_mats[technologie.lower()]

    # Filter by High Level Material
    df = df[
        (df['High Level Material'].isin(['die','carrier','encapsulation','finishing'])) |
        ((df['High Level Material'] == 'connection') & 
         (df['Homogeneous Material'].isin(tech_allowed)))
    ].copy()

    # Compute carrier mass based on socket
    carrier_mass = 57.753 + 0.309 * surface_mm2 if socket=="LGA" else -34.658 + 1.895 * surface_mm2

    # Compute mass allocation
    grouped = df.groupby(['High Level Material','Homogeneous Material','Substances'], as_index=False)['Mass [mg]'].sum()
    grouped['fraction'] = grouped['Mass [mg]'] / grouped['Mass [mg]'].sum()

    carrier_frac = grouped.loc[grouped['High Level Material']=='carrier','fraction'].sum()
    non_carrier_frac = 1 - carrier_frac
    total_weight_target = weight_mg

    if carrier_frac > 0:
        carrier_target = carrier_mass
        non_carrier_target = total_weight_target - carrier_target
        grouped['mass_mg'] = grouped.apply(
            lambda r: (r['fraction']/carrier_frac)*carrier_target if r['High Level Material']=='carrier'
            else (r['fraction']/non_carrier_frac)*non_carrier_target, axis=1)
    else:
        grouped['mass_mg'] = grouped['fraction'] * total_weight_target

    # Adjust for yield
    y = yield_pct / 100 if yield_pct > 0 else 0.001
    grouped['mass_mg'] = grouped['mass_mg'] / y

    return grouped[['High Level Material','Homogeneous Material','Substances','mass_mg']]\
        .sort_values(['High Level Material','Homogeneous Material']).reset_index(drop=True)

# %%
def build_model_cpu(dfs_high_level, technologie="flip chip", socket="LGA",
                    surface_mm2=100.0, weight_mg=200.0, yield_pct=95.0):
    """
    Build CPU material model:

    - die/carrier/encapsulation/finishing: keep all from specified socket
    - connection: filter by technology allowed list
    - Carrier mass model (MCU-based) is used only as a RELATIVE estimator
    - Total CPU weight is authoritative
    - All masses renormalized to total CPU weight
    - Adjust for yield
    """

    import pandas as pd

    # Combine all input dataframes
    df = pd.concat(dfs_high_level, ignore_index=True)

    # Clean column names
    df.columns = df.columns.str.strip().str.replace('\n', '')

    socket = socket.upper()
    if socket not in ["LGA", "BGA"]:
        raise ValueError("Socket must be 'LGA' or 'BGA'")

    required_cols = {
        'Socket', 'High Level Material',
        'Homogeneous Material', 'Mass [mg]', 'Substances'
    }
    missing = required_cols - set(df.columns)
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # Keep only CPUs with the specified socket
    df = df[df['Socket'].str.upper() == socket].copy()
    if df.empty:
        raise ValueError(f"No CPUs with socket {socket} found")

    # Clean Homogeneous Material values
    df['Homogeneous Material'] = df['Homogeneous Material'].str.strip().str.lower()

    # Allowed homogeneous materials by technology
    tech_mats = {
        "flip chip": {"underfill", "lid", "lid platings", "metal lid", "bump", "plating"},
        "wire bonding": {"wire", "die", "die attach", "mold compound", "encapsulation"}
    }

    technologie = technologie.lower()
    if technologie not in tech_mats:
        raise ValueError(f"Unknown technology '{technologie}'")

    tech_allowed = tech_mats[technologie]

    # Filter materials
    df = df[
        (df['High Level Material'].isin(['die', 'carrier', 'encapsulation', 'finishing'])) |
        (
            (df['High Level Material'] == 'connection') &
            (df['Homogeneous Material'].isin(tech_allowed))
        )
    ].copy()

    # === Carrier mass model (MCU-based, RELATIVE ONLY) ===
    carrier_mass_model = (
        57.753 + 0.309 * surface_mm2
        if socket == "LGA"
        else -34.658 + 1.895 * surface_mm2
    )

    # === Aggregate base composition ===
    grouped = (
        df.groupby(
            ['High Level Material', 'Homogeneous Material', 'Substances'],
            as_index=False
        )['Mass [mg]'].sum()
    )

    grouped['fraction'] = grouped['Mass [mg]'] / grouped['Mass [mg]'].sum()

    carrier_frac_base = grouped.loc[
        grouped['High Level Material'] == 'carrier', 'fraction'
    ].sum()

    non_carrier_frac_base = 1 - carrier_frac_base

    # === Convert carrier model into bounded fraction of total weight ===
    carrier_frac_model = carrier_mass_model / weight_mg

    # Physical bounds (acknowledging MCU → CPU extrapolation uncertainty)
    carrier_frac_model = min(max(carrier_frac_model, 0.05), 0.90)

    carrier_target = carrier_frac_model * weight_mg
    non_carrier_target = weight_mg - carrier_target

    # === Allocate mass ===
    def allocate_mass(row):
        if row['High Level Material'] == 'carrier':
            return (row['fraction'] / carrier_frac_base) * carrier_target
        else:
            return (row['fraction'] / non_carrier_frac_base) * non_carrier_target

    grouped['mass_mg'] = grouped.apply(allocate_mass, axis=1)

    # === Adjust for yield ===
    y = max(yield_pct / 100.0, 0.001)
    grouped['mass_mg'] = grouped['mass_mg'] / y

    return (
        grouped[
            ['High Level Material', 'Homogeneous Material', 'Substances', 'mass_mg']
        ]
        .sort_values(['High Level Material', 'Homogeneous Material'])
        .reset_index(drop=True)
    )

# %%
def plot_cpu_substances(model_cpu, category='hm'):
    """
    Plot CPU material composition with Plotly.
    Parameters:
        model_cpu: DataFrame with ['High Level Material','Homogeneous Material','Substances','mass_mg']
        category: 'hl' for High Level Material, 'hm' for Homogeneous Material
    Returns:
        fig_abs, fig_pct : Plotly figures
    """
    df = model_cpu.copy()
    if not {'High Level Material','Homogeneous Material','Substances','mass_mg'}.issubset(df.columns):
        raise ValueError("model_cpu must have required columns")

    # remove zero-mass substances
    df = df[df['mass_mg'] > 0]

    # choose grouping category
    if category.lower() == 'hl':
        group_col = 'High Level Material'
    elif category.lower() == 'hm':
        group_col = 'Homogeneous Material'
    else:
        raise ValueError("category must be 'hl' or 'hm'")

    # aggregate for absolute plot
    agg_abs = df.groupby([group_col,'Substances'], as_index=False)['mass_mg'].sum()
    fig_abs = px.bar(
        agg_abs, x=group_col, y='mass_mg', color='Substances',
        title=f'CPU Material Composition by {group_col} (mg)',
        labels={'mass_mg':'Mass [mg]'}, barmode='stack'
    )
    fig_abs.update_layout(xaxis_title=group_col, hovermode='x unified')

    # aggregate for percentage plot
    total_weight = df['mass_mg'].sum()
    df['mass_pct'] = df['mass_mg'] / total_weight * 100
    agg_pct = df.groupby([group_col,'Substances'], as_index=False)['mass_pct'].sum()
    fig_pct = px.bar(
        agg_pct, x=group_col, y='mass_pct', color='Substances',
        title=f'CPU Material Composition by {group_col} (% of total weight)',
        labels={'mass_pct':'% of total CPU weight'}, barmode='stack'
    )
    fig_pct.update_layout(xaxis_title=group_col, hovermode='x unified')

    fig_abs.show()
    fig_pct.show()
    return fig_abs, fig_pct

# %%
model_Intel_Xeon_Bronze = build_model_cpu(
    dfs_high_level,
    technologie="flip chip",
    socket="LGA",
    surface_mm2=4256,  # 4256
    weight_mg=2800, # 11310
    yield_pct=99
)

model_Intel_Xeon_Bronze.to_excel("model_Intel_Xeon_Bronze.xlsx")

# %%
fig_abs, fig_pct = plot_cpu_substances(model_Intel_Xeon_Bronze, "hl")

# %%
pd.options.display.max_rows = 2000

print(model_Intel_Xeon_Bronze.all)
# Out:
# <bound method DataFrame.all of     High Level Material Homogeneous Material  \
# 0               carrier           leadfinish
# 1               carrier           leadfinish
# 2               carrier            substrate
# 3               carrier            substrate
# 4               carrier            substrate
# 5               carrier            substrate
# 6               carrier            substrate
# 7               carrier            substrate
# 8               carrier            substrate
# 9               carrier            substrate
# 10              carrier            substrate
# 11              carrier            substrate
# 12              carrier            substrate
# 13              carrier            substrate
# 14              carrier            substrate
# 15              carrier            substrate
# 16              carrier            substrate
# 17              carrier            substrate
# 18              carrier            substrate
# 19              carrier            substrate
# 20              carrier            substrate
# 21              carrier            substrate
# 22              carrier            substrate
# 23              carrier            substrate
# 24              carrier            substrate
# 25              carrier            substrate
# 26              carrier            substrate
# 27              carrier            substrate
# 28              carrier            substrate
# 29              carrier            substrate
# 30              carrier            substrate
# 31              carrier            substrate
# 32              carrier            substrate
# 33              carrier            substrate
# 34              carrier            substrate
# 35              carrier            substrate
# 36              carrier            substrate
# 37              carrier            substrate
# 38              carrier            substrate
# 39              carrier            substrate
# 40              carrier            substrate
# 41              carrier            substrate
# 42              carrier            substrate
# 43              carrier            substrate
# 44              carrier      substrate metal
# 45              carrier    substrate plastic
# 46              carrier    substrate plastic
# 47              carrier    substrate plastic
# 48           connection                 bump
# 49           connection                 bump
# 50           connection                 bump
# 51           connection            underfill
# 52           connection            underfill
# 53           connection            underfill
# 54           connection            underfill
# 55           connection            underfill
# 56           connection            underfill
# 57           connection            underfill
# 58           connection            underfill
# 59                  die               chip_1
# 60                  die               chip_2
# 61                  die                  die
# 62                  die                  die
# 63                  die                  die
# 64                  die                  die
# 65                  die                  die
# 66                  die                  die
# 67                  die                  die
# 68                  die                  die
# 69                  die                  die
# 70                  die                  die
# 71                  die                  die
# 72                  die                  die
# 73                  die                  die
# 74                  die                  die
# 75                  die           die attach
# 76                  die           die attach
# 77                  die           die attach
# 78        encapsulation        encapsulation
# 79        encapsulation        encapsulation
# 80        encapsulation                  lid
# 81        encapsulation                  lid
# 82        encapsulation         lid platings
# 83        encapsulation         lid platings
# 84        encapsulation         lid platings
# 85        encapsulation            metal lid
# 86        encapsulation            metal lid
# 87        encapsulation            metal lid
# 88        encapsulation            metal lid
# 89        encapsulation            metal lid
# 90        encapsulation            metal lid
# 91        encapsulation            metal lid
# 92        encapsulation            metal lid
# 93        encapsulation            metal lid
# 94        encapsulation            metal lid
# 95        encapsulation            metal lid
# 96        encapsulation            metal lid
# 97        encapsulation            metal lid
# 98        encapsulation            metal lid
# 99        encapsulation        mold compound
# 100       encapsulation        mold compound
# 101       encapsulation        mold compound
# 102       encapsulation        mold compound
# 103       encapsulation        mold compound
# 104       encapsulation        mold compound
# 105       encapsulation        mold compound
# 106       encapsulation        mold compound
# 107       encapsulation        mold compound
# 108       encapsulation        mold compound
# 109       encapsulation        mold compound
# 110       encapsulation        mold compound
# 111       encapsulation        mold compound
# 112       encapsulation        mold compound
# 113       encapsulation        mold compound
# 114       encapsulation        mold compound
# 115       encapsulation        mold compound
# 116       encapsulation        mold compound
# 117       encapsulation              plating
# 118       encapsulation              plating
# 119       encapsulation              plating
# 120       encapsulation              plating
# 121           finishing              coating
# 122           finishing              coating
# 123           finishing              coating
# 124           finishing              coating
# 125           finishing              coating
# 126           finishing              coating
# 127           finishing            finishing
# 128           finishing            finishing
# 129           finishing                 glue
# 130           finishing                 glue
# 131           finishing                 glue
# 132           finishing                 glue
# 133           finishing                 glue
# 134           finishing                 glue
# 135           finishing                 glue
#
#                                      Substances     mass_mg
# 0                                          gold    0.458436
# 1                                        nickel    0.523308
# 2                                       alumina  139.437925
# 3                           aluminium hydroxide    2.071610
# 4                                aluminum oxide  894.226083
# 5                              amorphous silica    5.695845
# 6                                barium sulfate    2.780887
# 7                          bismaleimide polymer    1.089866
# 8                                    bismethane    1.332058
# 9                  bisphenol f type epoxy resin    0.856323
# 10                                        boron    0.004325
# 11                                calcium oxide    5.816941
# 12                              calcium sulfate    0.038924
# 13                                 calciumoxide    0.462760
# 14                               chromium oxide   46.544181
# 15                                chromiumoxide    5.994261
# 16                                       copper    0.562232
# 17                   copper phthalocyanine bule    0.012975
# 18                                           cu    6.911132
# 19                                  fiber glass    3.252297
# 20                                  glass fiber    6.539194
# 21                                         gold    1.556951
# 22                              magnesium oxide    4.653553
# 23                               magnesiumoxide    0.769826
# 24                 methoxymethylethoxy propanol    0.211918
# 25                                   molybdenum    9.722293
# 26                                       nickel    5.423379
# 27                    other aluminium compounds    0.012975
# 28                        other inoranic filler    1.998087
# 29               other miscellaneous substances    0.147045
# 30                                    palladium    0.034599
# 31          phenolic polymer resin, epikote 155    1.332058
# 32                                   phosphorus    0.233543
# 33                   polymerized biphenyl resin    0.345989
# 34             proprietary material-cured resin    3.749657
# 35                              silicon dioxide   46.600405
# 36        talc containing no asbestiform fibers    0.211918
# 37                                       talc4)    0.220568
# 38                          thermosetting resin    1.825092
# 39                                 titandioxide    1.535327
# 40                               titanium oxide   11.633883
# 41                                     triazine    2.421924
# 42                                     tungsten  118.060125
# 43                               zinc hydroxide    0.021624
# 44                                       copper   34.957872
# 45                           aluminiumhydroxide    3.970225
# 46                  bismaleimide triazine resin    3.606936
# 47                                  glass fibre    6.854909
# 48                                       copper    0.060759
# 49                                       silver    0.008680
# 50                                          tin    0.286436
# 51                           1,6-bisnaphthalene    0.143218
# 52                                    additives    0.030380
# 53                          amine type hardener    0.099819
# 54                            bismuth compounds    0.013020
# 55               bisphenol a liquid epoxy resin    0.056419
# 56               bisphenol f liquid epoxy resin    0.143218
# 57                                 carbon black    0.013020
# 58                              silicon dioxide    0.933087
# 59                                      silicon   88.734399
# 60                                      silicon   21.539119
# 61                                    aluminium    0.911387
# 62                                       cobalt    0.008680
# 63                                       copper   28.535101
# 64                            lead-borate glass    0.000000
# 65                                       nickel    1.301982
# 66                                    polyimide    1.614457
# 67                                      silicon  292.268874
# 68                              silicon nitride    0.091139
# 69                                silicon oxide    5.455304
# 70                                       silver    0.004340
# 71                                     tantalum    0.013020
# 72                                          tin    0.104159
# 73                                     titanium    0.095479
# 74                                     tungsten    0.073779
# 75                                  epoxy resin    2.873040
# 76                  phenol-formaldehyde polymer    2.873040
# 77                              silicon dioxide   22.572024
# 78                               silicondioxide    0.156238
# 79                               silicone resin    1.401800
# 80                                       copper   45.981657
# 81                                         zinc   24.759354
# 82                                         gold    0.026040
# 83                                       nickel    2.321868
# 84                                   phosphorus    1.288962
# 85            3-glycidoxypropyltrimethoxysilane    0.073779
# 86           bisphenol a diglycidyl ether resin    8.376083
# 87                                       carbon    0.360215
# 88                                 carbon black    0.138878
# 89                                     chromium  123.497313
# 90                                         gold    0.026040
# 91                                         iron  596.433521
# 92                                    manganese    3.619509
# 93             methyl methacrylate crosspolymer    0.138878
# 94                                       nickel    0.112838
# 95                                   phosphorus    0.216997
# 96                                      silicon    2.187329
# 97                                       sulfur    0.230017
# 98                                   zinc oxide   14.486717
# 99                                 carbon black    1.223863
# 100                 dimer acid diglycidyl ester    0.438334
# 101                              epon resin 828    1.553698
# 102                                 epoxy resin    8.041908
# 103                             metal hydroxide    1.679557
# 104                               miscellaneous    0.000000
# 105              other miscellaneous substances    0.559852
# 106                     polytetrafluoroethylene    4.804313
# 107     proprietary material-other epoxy resins    2.239409
# 108  proprietary material-other phenolic resins    1.679557
# 109                  silica vitreous 60676-86-0   39.020394
# 110           silica, vitreous [ fused silica ]   49.549087
# 111               silicon dioxide cas 7631-86-9    7.759812
# 112                              silicondioxide    1.788055
# 113                                      silver    2.491125
# 114           sumitomo-molding-epoxy resin a-ip    1.553698
# 115            sumitomo-molding-phenol resin-ip    1.553698
# 116                                titandioxide    0.073779
# 117                                      cobalt    0.147558
# 118                                        gold    0.221337
# 119                               miscellaneous    0.000000
# 120                                      nickel    0.650991
# 121                                   additives    0.273416
# 122                                      copper    5.207927
# 123                                      filler    0.273416
# 124                                        gold    0.312476
# 125                                      nickel    1.445200
# 126                                    silicone    4.934511
# 127                                        gold    1.267262
# 128                                      nickel    1.445200
# 129                                carbon black    0.000000
# 130                               dicyandiamide    0.616271
# 131                           dimethyl siloxane    0.121518
# 132                                 epoxy resin    1.601438
# 133                                     oxirane    0.121518
# 134                              silicondioxide    0.086799
# 135                                    silicone    0.130198  >

# %%
# Updated mapping including missing substances
DIRECT_MAPPING = {
    "gold": "Gold()",
    "nickel": "Nickel()",
    "alumina": "AluminiumOxide()",
    "aluminium hydroxide": "AluminiumHydroxide()",
    "aluminiumhydroxide":"AluminiumHydroxide()",
    "aluminum oxide": "AluminiumOxide()",
    "amorphous silica": "Silica()",
    "barium sulfate": "BariumSulfide()",
    "bismaleimide polymer": "EpoxyResin()",
    "bismethane": "Pentane()",
    "bisphenol f type epoxy resin": "BisphenolAEpoxy()",
    "bisphenol a diglycidyl ether resin": "BisphenolAEpoxy()",
    "boron": "BoronCarbide()",
    "calcium oxide": "HydratedLime()",
    "calcium sulfate": "HydratedLime()",
    "calciumoxide": "HydratedLime()",
    "chromium oxide": "Chromium()",
    "chromiumoxide": "Chromium()",
    "copper": "Copper()",
    "copper phthalocyanine bule": "Copper()",
    "cu": "Copper()",
    "dimethyl siloxane": "SiliconeTetrachloride()",
    "fiber glass": "GlassFibre()",
    "glass fiber": "GlassFibre()",
    "glass fibre": "GlassFibre()",
    "magnesium oxide": "MagnesiumOxide()",
    "magnesiumoxide": "MagnesiumOxide()",
    "methoxymethylethoxy propanol": "MethoxyPropanol()",
    "molybdenum": "Molybdenum()",
    "other aluminium compounds": "AluminiumIngot()",
    "other inoranic filler": "InorganicChemicals()",
    "phenolic polymer resin, epikote 155": "PhenolicResin()",
    "phosphorus": "PhosphorousChloride()",
    "polymerized biphenyl resin": "EpoxyResin()",
    "proprietary material-cured resin": "EpoxyResin()",
    "silicon dioxide": "Silicone()",
    "talc containing no asbestiform fibers": "MagnesiumOxide()",
    "talc4)": "MagnesiumOxide()",
    "thermosetting resin": "EpoxyResin()",
    "titandioxide": "TitaniumDioxide()",
    "titanium oxide": "TitaniumDioxide()",
    "triazine": "Triazine()",
    "tungsten": "Tungsten()",
    "zinc hydroxide": "ZincOxide()",
    "zinc": "ZincOxide()",
    "bismaleimide triazine resin": "Triazine()",
    "silver": "Silver()",
    "tin": "Tin()",
    "1,6-bisnaphthalene": "EpoxyResin()",
    "3-glycidoxypropyltrimethoxysilane": "EpoxyResin()",
    "additives": "PhthalicAnhydride()",
    "amine type hardener": "Piperidine()",
    "bisphenol a liquid epoxy resin": "BisphenolAEpoxy()",
    "bisphenol f liquid epoxy resin": "BisphenolAEpoxy()",
    "carbon black": "CarbonBlack()",
    "silicondioxide": "Silica()",
    "silicone resin": "Silicone()",
    "silicone": "Silicone()",
    "carbon": "CarbonBlack()",
    "chromium": "Chromium()",
    "iron": "PigIron()",
    "manganese": "Manganese()",
    "methyl methacrylate crosspolymer": "MethylMethacrylate()",
    "silicon": "Silicone()",
    "sulfur": "Sulfur()",
    "dimer acid diglycidyl ester": "Adhesive()",
    "epon resin 828": "EpoxyResin()",
    "epoxy resin": "EpoxyResin()",
    "metal hydroxide": "AluminiumHydroxide()",
    "polytetrafluoroethylene": "PolytetraFluoroEthylene()",
    "proprietary material-other epoxy resins": "EpoxyResin()",
    "proprietary material-other phenolic resins": "PhenolicResin()",
    "silica vitreous 60676-86-0": "Silica()",
    "silica, vitreous [ fused silica ]": "Silica()",
    "silicon dioxide cas 7631-86-9": "Silicone()",
    "silicondioxide": "Silicone()",
    "sumitomo-molding-epoxy resin a-ip": "EpoxyResin()",
    "sumitomo-molding-phenol resin-ip": "EpoxyResin()",
    "cobalt": "Cobalt()",
    "dicyandiamide": "Nitrile()",
    "dimethyl siloxane": "Silicone()",
    "oxirane": "EthyleneOxide()",
    "filler": "CalciumCarbonate()",
    "palladium": "Palladium()",
    "silicone tetrachloride": "SiliconeTetrachloride()",
}

def generate_exchange(df: pd.DataFrame):
    grouped = {}
    for _, row in df.iterrows():
        hlm = row["High Level Material"].upper()
        substance = row["Substances"].strip().lower()
        mass = row["mass_mg"]

        terminal_class = DIRECT_MAPPING.get(substance)
        if not terminal_class:
            continue  # skip unknowns

        # Round mass to 15 significant digits (like your desired output)
        mass_str = f"{mass:.15g}"

        entry = f"    Exchange({mass_str} * 1e-6, {terminal_class}),"
        grouped.setdefault(hlm, []).append(entry)

    # Output string
    result = ""
    for hlm, entries in grouped.items():
        result += f"{hlm}: list[Exchange] = [\n"
        for e in entries:
            result += e + "\n"
        result += "]\n\n"
    return result

# Example usage:
print(generate_exchange(model_Intel_Xeon_Bronze))
# Out:
# CARRIER: list[Exchange] = [
#     Exchange(0.458435534234561 * 1e-6, Gold()),
#     Exchange(0.523308487192282 * 1e-6, Nickel()),
#     Exchange(139.437925087325 * 1e-6, AluminiumOxide()),
#     Exchange(2.07160963111655 * 1e-6, AluminiumHydroxide()),
#     Exchange(894.226083023347 * 1e-6, AluminiumOxide()),
#     Exchange(5.6958452696879 * 1e-6, Silica()),
#     Exchange(2.78088725012097 * 1e-6, BariumSulfide()),
#     Exchange(1.08986560968971 * 1e-6, EpoxyResin()),
#     Exchange(1.33205796739854 * 1e-6, Pentane()),
#     Exchange(0.856322979041916 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0.00432486353051473 * 1e-6, BoronCarbide()),
#     Exchange(5.81694144854231 * 1e-6, HydratedLime()),
#     Exchange(0.0389237717746325 * 1e-6, HydratedLime()),
#     Exchange(0.462760397765076 * 1e-6, HydratedLime()),
#     Exchange(46.5441813153995 * 1e-6, Chromium()),
#     Exchange(5.99426085329341 * 1e-6, Chromium()),
#     Exchange(0.562232258966915 * 1e-6, Copper()),
#     Exchange(0.0129745905915442 * 1e-6, Copper()),
#     Exchange(6.91113192176253 * 1e-6, Copper()),
#     Exchange(3.25229737494708 * 1e-6, GlassFibre()),
#     Exchange(6.53919365813827 * 1e-6, GlassFibre()),
#     Exchange(1.5569508709853 * 1e-6, Gold()),
#     Exchange(4.65355315883385 * 1e-6, MagnesiumOxide()),
#     Exchange(0.769825708431622 * 1e-6, MagnesiumOxide()),
#     Exchange(0.211918312995222 * 1e-6, MethoxyPropanol()),
#     Exchange(9.72229321659711 * 1e-6, Molybdenum()),
#     Exchange(5.42337886726547 * 1e-6, Nickel()),
#     Exchange(0.0129745905915442 * 1e-6, AluminiumIngot()),
#     Exchange(1.9980869510978 * 1e-6, InorganicChemicals()),
#     Exchange(0.0345989082441178 * 1e-6, Palladium()),
#     Exchange(1.33205796739854 * 1e-6, PhenolicResin()),
#     Exchange(0.233542630647795 * 1e-6, PhosphorousChloride()),
#     Exchange(0.345989082441178 * 1e-6, EpoxyResin()),
#     Exchange(3.74965668095627 * 1e-6, EpoxyResin()),
#     Exchange(46.6004045412962 * 1e-6, Silicone()),
#     Exchange(0.211918312995222 * 1e-6, MagnesiumOxide()),
#     Exchange(0.220568040056251 * 1e-6, MagnesiumOxide()),
#     Exchange(1.82509240987722 * 1e-6, EpoxyResin()),
#     Exchange(1.53532655333273 * 1e-6, TitaniumDioxide()),
#     Exchange(11.6338828970846 * 1e-6, TitaniumDioxide()),
#     Exchange(2.42192357708825 * 1e-6, Triazine()),
#     Exchange(118.060124655991 * 1e-6, Tungsten()),
#     Exchange(0.0216243176525736 * 1e-6, ZincOxide()),
#     Exchange(34.9578719171505 * 1e-6, Copper()),
#     Exchange(3.97022472101252 * 1e-6, AluminiumHydroxide()),
#     Exchange(3.60693618444928 * 1e-6, Triazine()),
#     Exchange(6.85490869586584 * 1e-6, GlassFibre()),
# ]
#
# CONNECTION: list[Exchange] = [
#     Exchange(0.0607591505385045 * 1e-6, Copper()),
#     Exchange(0.00867987864835779 * 1e-6, Silver()),
#     Exchange(0.286435995395807 * 1e-6, Tin()),
#     Exchange(0.143217997697904 * 1e-6, EpoxyResin()),
#     Exchange(0.0303795752692523 * 1e-6, PhthalicAnhydride()),
#     Exchange(0.0998186044561146 * 1e-6, Piperidine()),
#     Exchange(0.0564192112143256 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0.143217997697904 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0.0130198179725367 * 1e-6, CarbonBlack()),
#     Exchange(0.933086954698462 * 1e-6, Silicone()),
# ]
#
# DIE: list[Exchange] = [
#     Exchange(88.7343994221617 * 1e-6, Silicone()),
#     Exchange(21.5391188658999 * 1e-6, Silicone()),
#     Exchange(0.00867987864835779 * 1e-6, Cobalt()),
#     Exchange(28.5351010564762 * 1e-6, Copper()),
#     Exchange(1.30198179725367 * 1e-6, Nickel()),
#     Exchange(292.268873847504 * 1e-6, Silicone()),
#     Exchange(0.0043399393241789 * 1e-6, Silver()),
#     Exchange(0.104158543780293 * 1e-6, Tin()),
#     Exchange(0.0737789685110412 * 1e-6, Tungsten()),
#     Exchange(2.87303983260643 * 1e-6, EpoxyResin()),
#     Exchange(22.5720244250544 * 1e-6, Silicone()),
# ]
#
# ENCAPSULATION: list[Exchange] = [
#     Exchange(0.15623781567044 * 1e-6, Silicone()),
#     Exchange(1.40180040170978 * 1e-6, Silicone()),
#     Exchange(45.9816571396754 * 1e-6, Copper()),
#     Exchange(24.7593538444406 * 1e-6, ZincOxide()),
#     Exchange(0.0260396359450734 * 1e-6, Gold()),
#     Exchange(2.32186753843571 * 1e-6, Nickel()),
#     Exchange(1.28896197928113 * 1e-6, PhosphorousChloride()),
#     Exchange(0.0737789685110412 * 1e-6, EpoxyResin()),
#     Exchange(8.37608289566527 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0.360214963906848 * 1e-6, CarbonBlack()),
#     Exchange(0.138878058373725 * 1e-6, CarbonBlack()),
#     Exchange(123.497313408835 * 1e-6, Chromium()),
#     Exchange(0.0260396359450734 * 1e-6, Gold()),
#     Exchange(596.433521382581 * 1e-6, PigIron()),
#     Exchange(3.6195093963652 * 1e-6, Manganese()),
#     Exchange(0.138878058373725 * 1e-6, MethylMethacrylate()),
#     Exchange(0.112838422428651 * 1e-6, Nickel()),
#     Exchange(0.216996966208945 * 1e-6, PhosphorousChloride()),
#     Exchange(2.18732941938616 * 1e-6, Silicone()),
#     Exchange(0.230016784181481 * 1e-6, Sulfur()),
#     Exchange(1.22386288941845 * 1e-6, CarbonBlack()),
#     Exchange(0.438333871742069 * 1e-6, Adhesive()),
#     Exchange(1.55369827805604 * 1e-6, EpoxyResin()),
#     Exchange(8.04190756770349 * 1e-6, EpoxyResin()),
#     Exchange(1.67955651845723 * 1e-6, AluminiumHydroxide()),
#     Exchange(4.80431283186604 * 1e-6, PolytetraFluoroEthylene()),
#     Exchange(2.23940869127631 * 1e-6, EpoxyResin()),
#     Exchange(1.67955651845723 * 1e-6, PhenolicResin()),
#     Exchange(39.0203944636924 * 1e-6, Silica()),
#     Exchange(49.5490872641505 * 1e-6, Silica()),
#     Exchange(7.75981151163186 * 1e-6, Silicone()),
#     Exchange(1.7880550015617 * 1e-6, Silicone()),
#     Exchange(2.49112517207869 * 1e-6, Silver()),
#     Exchange(1.55369827805604 * 1e-6, EpoxyResin()),
#     Exchange(1.55369827805604 * 1e-6, EpoxyResin()),
#     Exchange(0.0737789685110412 * 1e-6, TitaniumDioxide()),
#     Exchange(0.147557937022082 * 1e-6, Cobalt()),
#     Exchange(0.221336905533124 * 1e-6, Gold()),
#     Exchange(0.650990898626834 * 1e-6, Nickel()),
# ]
#
# FINISHING: list[Exchange] = [
#     Exchange(0.27341617742327 * 1e-6, PhthalicAnhydride()),
#     Exchange(5.20792718901467 * 1e-6, Copper()),
#     Exchange(0.27341617742327 * 1e-6, CalciumCarbonate()),
#     Exchange(0.31247563134088 * 1e-6, Gold()),
#     Exchange(1.44519979495157 * 1e-6, Nickel()),
#     Exchange(4.9345110115914 * 1e-6, Silicone()),
#     Exchange(1.26726228266024 * 1e-6, Gold()),
#     Exchange(1.44519979495157 * 1e-6, Nickel()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0.616271384033403 * 1e-6, Nitrile()),
#     Exchange(0.121518301077009 * 1e-6, Silicone()),
#     Exchange(1.60143761062201 * 1e-6, EpoxyResin()),
#     Exchange(0.121518301077009 * 1e-6, EthyleneOxide()),
#     Exchange(0.0867987864835779 * 1e-6, Silicone()),
#     Exchange(0.130198179725367 * 1e-6, Silicone()),
# ]

# %%
model_BGA = build_model_cpu(
    dfs_high_level,
    technologie="wire bonding",
    socket="BGA",
    surface_mm2=4256,  # 4256
    weight_mg=2800, # 11310
    yield_pct=99
)

print(generate_exchange(model_BGA))
# Out:
# CARRIER: list[Exchange] = [
#     Exchange(0.0702466138250825 * 1e-6, HydratedLime()),
#     Exchange(6.17661168227211 * 1e-6, GlassFibre()),
#     Exchange(0.00101806686703018 * 1e-6, Gold()),
#     Exchange(0.140493227650165 * 1e-6, AluminiumHydroxide()),
#     Exchange(0.00712646806921127 * 1e-6, Nickel()),
#     Exchange(0.00101806686703018 * 1e-6, Palladium()),
#     Exchange(3.46651768223777 * 1e-6, EpoxyResin()),
#     Exchange(2.07074800753939 * 1e-6, Triazine()),
#     Exchange(0.0427588084152676 * 1e-6, ZincOxide()),
#     Exchange(301.460798063174 * 1e-6, AluminiumHydroxide()),
#     Exchange(274.055456069589 * 1e-6, Triazine()),
#     Exchange(4.35936232462324 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0.089589884298656 * 1e-6, HydratedLime()),
#     Exchange(1208.33541994319 * 1e-6, Copper()),
#     Exchange(48.3164354423854 * 1e-6, EpoxyResin()),
#     Exchange(7.82995227432913 * 1e-6, GlassFibre()),
#     Exchange(520.705570145592 * 1e-6, GlassFibre()),
#     Exchange(0.0824634162294447 * 1e-6, Gold()),
#     Exchange(0.178161701730282 * 1e-6, AluminiumHydroxide()),
#     Exchange(0.312953754925078 * 1e-6, Nickel()),
#     Exchange(0.0477249385926409 * 1e-6, Palladium()),
#     Exchange(0.16899909992701 * 1e-6, MagnesiumOxide()),
#     Exchange(2.65104612174659 * 1e-6, Triazine()),
# ]
#
# CONNECTION: list[Exchange] = [
#     Exchange(0.463524084391642 * 1e-6, Copper()),
#     Exchange(1.1363319858764 * 1e-6, Gold()),
#     Exchange(0.000879343769298824 * 1e-6, Palladium()),
# ]
#
# DIE: list[Exchange] = [
#     Exchange(0.01494884407808 * 1e-6, Copper()),
#     Exchange(0.00461655478881882 * 1e-6, Gold()),
#     Exchange(14.0568597420975 * 1e-6, Silicone()),
#     Exchange(0.0347340788873035 * 1e-6, EpoxyResin()),
# ]
#
# ENCAPSULATION: list[Exchange] = [
#     Exchange(0.524198804473261 * 1e-6, CarbonBlack()),
#     Exchange(32.2385012700335 * 1e-6, EpoxyResin()),
#     Exchange(114.433071663789 * 1e-6, Silicone()),
#     Exchange(114.905938775729 * 1e-6, Silicone()),
#     Exchange(0.0111017150873976 * 1e-6, CarbonBlack()),
#     Exchange(0.368774793249694 * 1e-6, EpoxyResin()),
#     Exchange(0.574870989179106 * 1e-6, Silver()),
#     Exchange(0.25786756034688 * 1e-6, Gold()),
#     Exchange(0.705783292833468 * 1e-6, Nickel()),
# ]
#
# FINISHING: list[Exchange] = [
#     Exchange(0.207085457669873 * 1e-6, EpoxyResin()),
#     Exchange(0.621256373009619 * 1e-6, Silver()),
# ]

# %%
fig_abs, fig_pct = plot_cpu_substances(model_BGA, 'hl')
