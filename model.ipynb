# %% [markdown]
# # **Model of CPU for Master Thesis**
#
# Arthur Removille at Resilio company

# %% [markdown]
# ### **Dataset :** MPU datasheets from STMicroelectronics and MPU datasheets from Infineon
#
# 1. LGA
#
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/0c/c1/60/5e/77/68/41/05/DM00013099/files/MD_O7%20SO%2008%20.15%20JEDEC_E7O7%20CPU016J.pdf/jcr:content/translations/en.MD_O7%20SO%2008%20.15%20JEDEC_E7O7%20CPU016J.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/18/9a/ee/7c/2e/72/4b/97/DM00825583/files/MD_A08N%20VFLGA2.5X3X.86%2014L%20P.5%20L.475X.25_22AA%20AU36ABC_vers2_signed.pdf/jcr:content/translations/en.MD_A08N%20VFLGA2.5X3X.86%2014L%20P.5%20L.475X.25_22AA%20AU36ABC_vers2_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/5d/8a/58/6b/86/12/48/d6/DM01104733/files/MD_A06R%20LGA%209.6X7.5%2018LD%20CERAMIC%20CAVITY_A2XZ%20AU23CDF_ver2-signed.pdf/jcr:content/translations/en.MD_A06R%20LGA%209.6X7.5%2018LD%20CERAMIC%20CAVITY_A2XZ%20AU23CDF_ver2-signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/98/a1/e0/01/27/36/4c/9c/DM01100634/files/MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf/jcr:content/translations/en.MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/e5/55/aa/da/5a/a3/40/33/DM00076551/files/MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf/jcr:content/translations/en.MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/e5/55/aa/da/5a/a3/40/33/DM00076551/files/MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf/jcr:content/translations/en.MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/9f/55/1f/91/15/47/47/88/DM00150211/files/MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf/jcr:content/translations/en.MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf
# https://www.infineon.com/row/public/documents/24/75/infineon-mcds-pasco2v15-ma006046957-materialcontentdatasheet-en.pdf
#
# 2. FCLGA
#
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/9f/55/1f/91/15/47/47/88/DM00150211/files/MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf/jcr:content/translations/en.MD_A0VT_FCLGA_4X4X0.8_WRAVAA4_signed.pdf
#
# 3. BGA
#
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/98/a1/e0/01/27/36/4c/9c/DM01100634/files/MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf/jcr:content/translations/en.MD_3N%20LLGA%203X3X1.0%2016L%20%20FOR%20SENSOR_D53N%20MT78ADA_ver2-signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/e5/55/aa/da/5a/a3/40/33/DM00076551/files/MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf/jcr:content/translations/en.MD_0E%20HLGA%204X3X1%204LD_B50EMT69AAA%20(MP34DTW01TR)_signed.pdf
# https://www.st.com/content/ccc/resource/quality_and_reliability/quality_certificate/material_declaration/group3/2c/24/58/7c/0b/69/45/93/DM00089983/files/MD_A0SZ%20LGA%206.5X4X1%2028%20L%20PITCH%200.6%20MM_21DFMV0HCCB%20(LSM330DS)%20WCP%20ver2_signed.pdf/jcr:content/translations/en.MD_A0SZ%20LGA%206.5X4X1%2028%20L%20PITCH%200.6%20MM_21DFMV0HCCB%20(LSM330DS)%20WCP%20ver2_signed.pdf
# https://www.infineon.com/row/public/documents/10/71/infineon-ma001226480-materialcontentsheet-en.pdf
# https://www.infineon.com/row/public/documents/10/71/infineon-ma001426600-materialcontentsheet-en.pdf
#
# (C:\Users\Arthur Resilio\Desktop\Resilio\Coding\metaboli_cpu_gpu_data\PGA_BGA_BOM.ods)

# %% [markdown]
# ## Imports :

# %%
import pandas as pd
import os
from urllib.parse import urlparse
import camelot
import re
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from plotly.express import get_trendline_results

# %% [markdown]
# ## Load the dataset and clean

# %%
# Folder containing Excel files
folder_path = r"C:\Users\Arthur Resilio\Desktop\Excel_cleaned"

# List all Excel files
all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(".xlsx")]

dfs = []

for file in all_files:
    try:
        df = pd.read_excel(file)

        # --- 1. Clean column names ---
        df.columns = (
            df.columns.astype(str)
            .str.strip()
            .str.replace('\n', ' ', regex=False)
            .str.replace('\r', '', regex=False)
            .str.replace('\xa0', ' ', regex=False)
        )

        # --- 2. Identify date columns (keep as datetime) ---
        date_columns = [col for col in df.columns if 'date' in col.lower()]
        for col in date_columns:
            try:
                df[col] = pd.to_datetime(df[col], errors='ignore')
            except:
                pass

        # --- 3. Convert mass/weight columns to numeric ---
        mass_columns = ['Mass [mg]', 'Weight [mg]', 'Mass\n[mg]', 'Weight\n[mg]']
        for col in mass_columns:
            if col in df.columns:
                df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

        dfs.append(df)

    except Exception as e:
        print(f"Error loading {file}: {e}")

print(f"Total datasets successfully loaded: {len(dfs)}")

# Optionally save dfs to a pickle for use in the next script
pd.to_pickle(dfs, r"C:\Users\Arthur Resilio\Desktop\dfs_loaded.pkl")

dfs = pd.read_pickle(r"C:\Users\Arthur Resilio\Desktop\dfs_loaded.pkl")

def clean_name(name):
    """Standardize text: lowercase, strip spaces, remove parentheses contents."""
    if not isinstance(name, str):
        return name
    name = name.strip()
    name = re.sub(r'\s+', ' ', name)  # collapse multiple spaces
    name = name.lower()
    name = re.sub(r'\s*\(.*?\)\s*', '', name)  # remove parentheses and contents
    return name

def compute_surface_from_first_two(size_series):
    """
    Compute surface using the first two valid numeric Size [mm] values for a given CPU.
    If only one value exists, assume square.
    """
    valid_sizes = pd.to_numeric(size_series, errors="coerce").dropna().values
    if len(valid_sizes) >= 2:
        return valid_sizes[0] * valid_sizes[1]
    elif len(valid_sizes) == 1:
        return valid_sizes[0] ** 2
    else:
        return None

def clean_bom_df(df):
    """
    Cleans a single CPU BOM DataFrame:
    - Forward fill CPU metadata (Name, Socket, Size, Date)
    - Standardize names and substances
    - Compute total mass and surface area per CPU
    """
    df = df.copy()

    # Forward fill CPU metadata
    for col in ['Name', 'Socket', 'Size [mm]', 'Date']:
        if col in df.columns:
            df[col] = df[col].ffill()

    # Standardize text columns
    for col in ['Homogeneous Material', 'Substances']:
        if col in df.columns:
            df[col] = df[col].apply(clean_name)

    # Convert mass column to numeric
    if 'Mass [mg]' in df.columns:
        df['Mass [mg]'] = pd.to_numeric(df['Mass [mg]'], errors='coerce').fillna(0)
    else:
        df['Mass [mg]'] = 0

    # Compute total CPU mass per Name
    df['CPU Total Mass [mg]'] = df.groupby('Name')['Mass [mg]'].transform('sum')

    # Compute surface per CPU from the first two valid size values
    df['Surface [mm²]'] = df.groupby('Name')['Size [mm]'].transform(compute_surface_from_first_two)

    return df

# Clean all DataFrames
dfs_high_level = [clean_bom_df(df) for df in dfs]

# Save cleaned DataFrames
output_path = r"C:\Users\Arthur Resilio\Desktop\dfs_cleaned.pkl"
pd.to_pickle(dfs_high_level, output_path)
# Out:
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# Total datasets successfully loaded: 10
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\3973268864.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_datetime(df[col], errors='ignore')

# %%
hm_set = set()
for df in dfs_high_level:
    if 'Homogeneous Material' in df.columns:
        hm_set.update(df['Homogeneous Material'].astype(str).str.strip().str.lower())

# Convert to sorted list
all_hm = sorted(hm_set)

# --- Initialize sets ---
hm_lga = set()
hm_bga = set()

# --- Iterate through each dataframe ---
for df in dfs_high_level:
    if 'Homogeneous Material' in df.columns and 'Socket' in df.columns:
        # Clean strings
        df["Homogeneous Material"] = df["Homogeneous Material"].astype(str).str.strip().str.lower()
        df["Socket"] = df["Socket"].astype(str).str.strip().str.upper()

        # Separate by socket type
        hm_lga.update(df.loc[df["Socket"] == "LGA", "Homogeneous Material"])
        hm_bga.update(df.loc[df["Socket"] == "BGA", "Homogeneous Material"])

# --- Convert to sorted lists ---
hm_lga = sorted(hm_lga)
hm_bga = sorted(hm_bga)

def group_homogeneous_material(dfs_cleaned):
    # Define mapping groups
    hm_mapping = {
        'die': ['chip_1', 'chip_2', 'die', 'die attach'],
        'carrier': ['cavity', 'leadfinish', 'leadframe', 'leadframe coating', 'substrate', 'substrate metal', 'substrate plastic',],
        'encapsulation': ['encapsulation', 'lid', 'lid platings', 'metal lid', 'mold compound', 'plating'],
        'connection': ['bump', 'wire', 'underfill', 'solder paste', 'solder resists', 'solderball','underfill'],
        'finishing': ['finishing', 'glue', 'coating', '']
    }

    # Create a flat mapping dictionary (value -> high level group)
    material_to_group = {}
    for group, materials in hm_mapping.items():
        for material in materials:
            material_to_group[material] = group

    dfs_high_level = []

    for df in dfs_cleaned:
        df_copy = df.copy()

        # Clean and map homogeneous material to high level group
        df_copy['High Level Material'] = (
            df_copy['Homogeneous Material']
            .astype(str).str.lower().str.strip()
            .map(material_to_group)  # Map to high level
            .fillna('other')  # For anything not in mapping
        )

        dfs_high_level.append(df_copy)

    return dfs_high_level

# %%
dfs_high_level = group_homogeneous_material(dfs_high_level)
#print(dfs_high_level[8].columns.tolist())
dfs_clean = [df.drop(columns=["Size [mm]", "Nb", "Date", "Material Group", "Homogeneous Material", "Substance Category", "Component mass [mg]", "CAS", "Concentration  in  homogeneous  material (ppm)", "Concentration  in  product (ppm)", "Level"], errors='ignore') for df in dfs_high_level]
dfs_clean[8].head()
# Out:
#            Name Socket Substances  Mass [mg]  CPU Total Mass [mg]  \
# 0  SAVT*WRAVAA4    LGA    silicon      0.800               29.389
# 1  SAVT*WRAVAA4    LGA  aluminium      0.003               29.389
# 2  SAVT*WRAVAA4    LGA     copper      0.061               29.389
# 3  SAVT*WRAVAA4    LGA   tantalum      0.003               29.389
# 4  SAVT*WRAVAA4    LGA   titanium      0.001               29.389
#
#    Surface [mm²] High Level Material
# 0           16.0                 die
# 1           16.0                 die
# 2           16.0                 die
# 3           16.0                 die
# 4           16.0                 die

# %% [markdown]
# ## Helper function to calculate standard deviation from a list of percentages

# %%
def calculate_stats(percentage_lists):
    """Calculate mean and standard deviation from a list of percentages."""
    stats = {}
    for key, percentages in percentage_lists.items():
        if percentages:
            stats[key] = {
                'Percentage': np.mean(percentages),
                'Std Dev': np.std(percentages)
            }
        else:
            stats[key] = {
                'Percentage': 0,
                'Std Dev': 0
            }
    return stats

# %% [markdown]
# ## Helper function to calculate the covariance matrix between beta and gamma
#
# Since they are both extracted from the same dataset there can be a correlation

# %%
def calculate_covariance(dfs_clean):
    covariance_results = {}

    for socket in ['LGA', 'BGA']:
        # Combine all dataframes for the current socket
        socket_df = pd.concat([df[df['Socket'] == socket] for df in dfs_clean], ignore_index=True)
        if socket_df.empty:
            continue

        # Get unique high-level materials and substances
        high_level_materials = socket_df['High Level Material'].unique()
        substances = socket_df['Substances'].unique()

        # Initialize a dictionary to store the data for each high-level material and substance
        data_dict = {material: {sub: [] for sub in substances} for material in high_level_materials}

        # Populate the data dictionary with the percentages
        for df in dfs_clean:
            sample_socket_df = df[df['Socket'] == socket]
            if sample_socket_df.empty:
                continue

            for material in high_level_materials:
                material_df = sample_socket_df[sample_socket_df['High Level Material'] == material]
                total_mass = material_df['Mass [mg]'].sum()

                for sub in substances:
                    sub_mass = material_df[material_df['Substances'] == sub]['Mass [mg]'].sum()
                    percentage = sub_mass / total_mass if total_mass else 0
                    data_dict[material][sub].append(percentage)

        # Create a DataFrame for each sample (row in the original data)
        sample_data = []
        for df in dfs_clean:
            sample_socket_df = df[df['Socket'] == socket]
            if sample_socket_df.empty:
                continue

            sample_data_row = {}
            for material in high_level_materials:
                material_df = sample_socket_df[sample_socket_df['High Level Material'] == material]
                total_mass = material_df['Mass [mg]'].sum()
                sample_data_row[material] = total_mass / sample_socket_df['CPU Total Mass [mg]'].iloc[0] if sample_socket_df['CPU Total Mass [mg]'].iloc[0] else 0

                for sub in substances:
                    sub_mass = material_df[material_df['Substances'] == sub]['Mass [mg]'].sum()
                    percentage = sub_mass / total_mass if total_mass else 0
                    sample_data_row[f"{material}_{sub}"] = percentage

            sample_data.append(sample_data_row)

        # Create a DataFrame from the sample data
        sample_df = pd.DataFrame(sample_data)

        # Calculate the covariance matrix
        cov_matrix = sample_df.cov().fillna(0)

        # Extract the covariance between beta (high-level materials) and gamma (substances)
        n_beta = len(high_level_materials)
        cov_beta = cov_matrix.loc[high_level_materials, high_level_materials].values
        cov_gamma = np.zeros((n_beta, n_beta))
        cov_beta_gamma = np.zeros((n_beta, n_beta))

        for i, material_i in enumerate(high_level_materials):
            for k, material_k in enumerate(high_level_materials):
                # Covariance between material_i and material_k's substances
                for sub in substances:
                    cov_gamma[i, k] += cov_matrix.loc[f"{material_i}_{sub}", f"{material_k}_{sub}"]
                    cov_beta_gamma[i, k] += cov_matrix.loc[material_i, f"{material_k}_{sub}"]

        # Normalize the covariance matrices
        cov_gamma /= len(substances)
        cov_beta_gamma /= len(substances)

        # Store the covariance matrices for the current socket
        covariance_results[socket] = {
            'cov_beta': cov_beta,
            'cov_gamma': cov_gamma,
            'cov_beta_gamma': cov_beta_gamma
        }

    return covariance_results

# %%
covariance_matrices = calculate_covariance(dfs_clean)
for socket, cov_matrix in covariance_matrices.items():
    print(f"Covariance matrix for {socket}:")
    display(cov_matrix)
# Out:
# Covariance matrix for LGA:
# {'cov_beta': array([[ 5.65506552e-03, -4.34493548e-04, -7.79626701e-03,
#           2.03714942e-03,  5.38545616e-04],
#         [-4.34493548e-04,  1.36236623e-04,  1.60096281e-03,
#          -1.39433327e-03,  9.16273809e-05],
#         [-7.79626701e-03,  1.60096281e-03,  4.72578342e-02,
#          -4.13925933e-02,  3.30063317e-04],
#         [ 2.03714942e-03, -1.39433327e-03, -4.13925933e-02,
#           4.22078780e-02, -1.45810084e-03],
#         [ 5.38545616e-04,  9.16273809e-05,  3.30063317e-04,
#          -1.45810084e-03,  4.97864524e-04]]),
#  'cov_gamma': array([[ 2.94784629e-03,  3.93691233e-05, -2.57802139e-04,
#          -3.05818937e-04,  1.26460318e-03],
#         [ 3.93691233e-05,  4.05736794e-03,  7.03314261e-07,
#          -2.47932674e-05,  7.00247500e-04],
#         [-2.57802139e-04,  7.03314261e-07,  5.54468272e-03,
#           8.21424236e-04, -3.27916736e-04],
#         [-3.05818937e-04, -2.47932674e-05,  8.21424236e-04,
#           3.91845217e-03, -3.05909484e-04],
#         [ 1.26460318e-03,  7.00247500e-04, -3.27916736e-04,
#          -3.05909484e-04,  4.50429836e-03]]),
#  'cov_beta_gamma': array([[ 5.39262836e-06,  1.35971141e-04,  8.11163243e-07,
#          -5.63785130e-20, -1.99429069e-05],
#         [ 1.08632910e-06,  2.73909860e-05,  1.63406447e-07,
#           7.58941521e-21, -2.36774149e-06],
#         [ 4.91643955e-06,  1.23964392e-04,  7.39534562e-07,
#          -1.04083409e-19, -5.95372181e-04],
#         [-1.27945507e-05, -3.22605144e-04, -1.92456600e-06,
#           8.67361738e-20,  5.76074050e-04],
#         [ 1.39915365e-06,  3.52786259e-05,  2.10461753e-07,
#           8.67361738e-21,  4.16087803e-05]])}
# Covariance matrix for BGA:
# {'cov_beta': array([[ 2.76359964e-02, -1.22995021e-02, -2.06726935e-02,
#           5.45039381e-03, -1.14194623e-04],
#         [-1.22995021e-02,  5.94262351e-03,  1.13443552e-02,
#          -5.01973298e-03,  3.22563903e-05],
#         [-2.06726935e-02,  1.13443552e-02,  4.25081371e-02,
#          -3.32387126e-02,  5.89138077e-05],
#         [ 5.45039381e-03, -5.01973298e-03, -3.32387126e-02,
#           3.27864327e-02,  2.16190866e-05],
#         [-1.14194623e-04,  3.22563903e-05,  5.89138077e-05,
#           2.16190866e-05,  1.40533839e-06]]),
#  'cov_gamma': array([[ 8.89220652e-05, -2.67819765e-06, -1.65792756e-07,
#          -7.79224136e-06, -6.49346379e-06],
#         [-2.67819765e-06,  7.76669440e-03, -3.70943268e-06,
#           3.98302063e-05,  1.27834060e-04],
#         [-1.65792756e-07, -3.70943268e-06,  9.87913884e-03,
#           6.17911934e-06,  5.37060482e-05],
#         [-7.79224136e-06,  3.98302063e-05,  6.17911934e-06,
#           2.88352390e-03, -1.31343335e-06],
#         [-6.49346379e-06,  1.27834060e-04,  5.37060482e-05,
#          -1.31343335e-06,  2.69396552e-03]]),
#  'cov_beta_gamma': array([[ 8.08478344e-20,  9.90736468e-20, -7.38362897e-04,
#          -2.54226716e-19, -8.30418873e-04],
#         [-4.05407493e-20, -2.45347474e-20,  3.95114271e-04,
#           8.59884482e-20,  2.34567220e-04],
#         [-1.43586689e-19,  2.54226716e-19,  1.73874932e-03,
#           5.23407945e-19,  4.28418927e-04],
#         [ 1.17766788e-19, -1.93474008e-19, -1.39890721e-03,
#          -1.49545127e-19,  1.57213160e-04],
#         [-1.66120686e-22, -1.16101930e-21,  3.40652210e-06,
#           1.43119360e-21,  1.02195663e-05]])}

# %% [markdown]
# ## **Calculation of $\vec\beta$**
#
# $\vec\beta : (5 \times 1)$
#
# $\Sigma_i \beta_i = 1$, i = 1,2,3,4,5
#
# Linear regression: % of the total mass of the CPU for each high level component

# %%
def high_level_mass_matrix(dfs_clean):
    results = {}

    for socket in ['LGA', 'BGA']:
        percentage_lists = {material: [] for material in pd.concat(dfs_clean)['High Level Material'].unique()}

        for df in dfs_clean:
            socket_df = df[df['Socket'] == socket]
            if socket_df.empty:
                continue

            total_mass = socket_df['Mass [mg]'].sum()
            for material in percentage_lists.keys():
                material_mass = socket_df[socket_df['High Level Material'] == material]['Mass [mg]'].sum()
                percentage = material_mass / total_mass if total_mass else 0
                percentage_lists[material].append(percentage)

        stats = calculate_stats(percentage_lists)
        results[socket] = pd.DataFrame.from_dict(stats, orient='index')

    return results

# %%
high_level_results = high_level_mass_matrix(dfs_clean)

print(f"High-Level Results for {"LGA"}:")
display(high_level_results["LGA"])
# Out:
# High-Level Results for LGA:
#                Percentage   Std Dev
# die              0.202549  0.067261
# connection       0.010956  0.010440
# encapsulation    0.398074  0.194438
# carrier          0.371777  0.183756
# finishing        0.016644  0.019957

# %% [markdown]
# ## **Calculation of matrix **$\gamma$****
#
# $\gamma : (5 \times A)$, lines are the 5 high level component, the columns are the A substances
#
# $\Sigma_j \gamma_{ij} = 1$, for i each of the high level components i = 1,...,5 and j = 1,..., A ; with A the number total of substances
#
# Linear regression: % of the mass of each substance inside each high level component

# %%
def substance_mass_matrices(dfs_clean):
    results = {}

    for socket in ['LGA', 'BGA']:
        socket_df = pd.concat([df[df['Socket'] == socket] for df in dfs_clean], ignore_index=True)
        if socket_df.empty:
            continue

        high_level_materials = socket_df['High Level Material'].unique()
        substances = socket_df['Substances'].unique()

        percentage_lists = {material: {sub: [] for sub in substances} for material in high_level_materials}

        for df in dfs_clean:
            sample_socket_df = df[df['Socket'] == socket]
            if sample_socket_df.empty:
                continue

            for material in high_level_materials:
                material_df = sample_socket_df[sample_socket_df['High Level Material'] == material]
                total_mass = material_df['Mass [mg]'].sum()

                for sub in substances:
                    sub_mass = material_df[material_df['Substances'] == sub]['Mass [mg]'].sum()
                    percentage = sub_mass / total_mass if total_mass else 0
                    percentage_lists[material][sub].append(percentage)

        # Initialize matrices
        percentage_matrix = pd.DataFrame(index=high_level_materials, columns=substances)
        std_dev_matrix = pd.DataFrame(index=high_level_materials, columns=substances)

        for material in high_level_materials:
            for sub in substances:
                percentages = percentage_lists[material][sub]
                if percentages:
                    percentage_matrix.loc[material, sub] = np.mean(percentages)
                    std_dev_matrix.loc[material, sub] = np.std(percentages)
                else:
                    percentage_matrix.loc[material, sub] = 0
                    std_dev_matrix.loc[material, sub] = 0

        results[socket] = {
            'Percentage': percentage_matrix.fillna(0),
            'Std Dev': std_dev_matrix.fillna(0)
        }

    return results

# %%
results = substance_mass_matrices(dfs_clean)

display(results['LGA']['Percentage'])
print("\nStandard Deviation Matrix:")
display(results['LGA']['Std Dev'])
# Out:
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Percentage': percentage_matrix.fillna(0),
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Std Dev': std_dev_matrix.fillna(0)
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Percentage': percentage_matrix.fillna(0),
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Std Dev': std_dev_matrix.fillna(0)
#                 silicon      gold  silicondioxide  silicone resin    nickel  \
# die            0.788598  0.000000        0.000000        0.000000  0.007735
# connection     0.000000  0.404750        0.000000        0.000000  0.000000
# encapsulation  0.000580  0.001909        0.019053        0.003686  0.012381
# carrier        0.000000  0.006073        0.000000        0.000000  0.023449
# finishing      0.000000  0.102412        0.006483        0.000000  0.148055
#
#                antimony       tin    zinc    copper  carbon black  ...  \
# die            0.000000  0.000619  0.0000  0.168832      0.000000  ...
# connection     0.008589  0.109135  0.0000  0.006796      0.001456  ...
# encapsulation  0.000000  0.000000  0.0651  0.120899      0.008985  ...
# carrier        0.000000  0.000000  0.0000  0.148618      0.000000  ...
# finishing      0.000000  0.000000  0.0000  0.149533      0.000000  ...
#
#                      cu  silica, vitreous [ fused silica ]  \
# die            0.000000                           0.000000
# connection     0.000000                           0.000000
# encapsulation  0.000000                           0.176994
# carrier        0.047602                           0.000000
# finishing      0.000000                           0.000000
#
#                proprietary material-other epoxy resins  \
# die                                           0.000000
# connection                                    0.000000
# encapsulation                                 0.007999
# carrier                                       0.000000
# finishing                                     0.000000
#
#                proprietary material-other phenolic resins  metal hydroxide  \
# die                                                 0.000            0.000
# connection                                          0.000            0.000
# encapsulation                                       0.006            0.006
# carrier                                             0.000            0.000
# finishing                                           0.000            0.000
#
#                1,6-bisnaphthalene  bisphenol f liquid epoxy resin  \
# die                      0.000000                        0.000000
# connection               0.016019                        0.016019
# encapsulation            0.000000                        0.000000
# carrier                  0.000000                        0.000000
# finishing                0.000000                        0.000000
#
#                bisphenol a liquid epoxy resin  amine type hardener  \
# die                                  0.000000             0.000000
# connection                           0.006311             0.011165
# encapsulation                        0.000000             0.000000
# carrier                              0.000000             0.000000
# finishing                            0.000000             0.000000
#
#                bismuth compounds
# die                     0.000000
# connection              0.001456
# encapsulation           0.000000
# carrier                 0.000000
# finishing               0.000000
#
# [5 rows x 100 columns]
# Standard Deviation Matrix:
#                 silicon      gold  silicondioxide  silicone resin    nickel  \
# die            0.347633  0.000000        0.000000        0.000000  0.015470
# connection     0.000000  0.482514        0.000000        0.000000  0.000000
# encapsulation  0.001160  0.003260        0.037088        0.007371  0.015106
# carrier        0.000000  0.004578        0.000000        0.000000  0.024140
# finishing      0.000000  0.183220        0.012966        0.000000  0.208480
#
#                antimony       tin      zinc    copper  carbon black  ...  \
# die            0.000000  0.001238  0.000000  0.337461      0.000000  ...
# connection     0.017178  0.151463  0.000000  0.013592      0.002913  ...
# encapsulation  0.000000  0.000000  0.130199  0.241798      0.012803  ...
# carrier        0.000000  0.000000  0.000000  0.273352      0.000000  ...
# finishing      0.000000  0.000000  0.000000  0.299065      0.000000  ...
#
#                      cu  silica, vitreous [ fused silica ]  \
# die            0.000000                           0.000000
# connection     0.000000                           0.000000
# encapsulation  0.000000                           0.353988
# carrier        0.095204                           0.000000
# finishing      0.000000                           0.000000
#
#                proprietary material-other epoxy resins  \
# die                                           0.000000
# connection                                    0.000000
# encapsulation                                 0.015999
# carrier                                       0.000000
# finishing                                     0.000000
#
#                proprietary material-other phenolic resins  metal hydroxide  \
# die                                              0.000000         0.000000
# connection                                       0.000000         0.000000
# encapsulation                                    0.011999         0.011999
# carrier                                          0.000000         0.000000
# finishing                                        0.000000         0.000000
#
#                1,6-bisnaphthalene  bisphenol f liquid epoxy resin  \
# die                      0.000000                        0.000000
# connection               0.032039                        0.032039
# encapsulation            0.000000                        0.000000
# carrier                  0.000000                        0.000000
# finishing                0.000000                        0.000000
#
#                bisphenol a liquid epoxy resin  amine type hardener  \
# die                                  0.000000              0.00000
# connection                           0.012621              0.02233
# encapsulation                        0.000000              0.00000
# carrier                              0.000000              0.00000
# finishing                            0.000000              0.00000
#
#                bismuth compounds
# die                     0.000000
# connection              0.002913
# encapsulation           0.000000
# carrier                 0.000000
# finishing               0.000000
#
# [5 rows x 100 columns]

# %% [markdown]
# ## **Calculation of the model**
#
# Inputs of the model (parameters) :
# - total CPU surface [mm $^2$] = $s$, (1 $\times$ 1)
# - total CPU mass [mg] = $w$, (1 $\times$ 1)
#
# Other inputs of the model and intermediate results :
# - high level components mass [mg] = $ \vec c $, $c_i$ with i = 1, 2, ... 5 ; (1 $\times$ 5). Calculated using the total mass $w$ using the function $g$
#
# Output of the model :
# - substances mass [mg] = $\vec m  = \vec c \times \vec \gamma $ ; are the masses of each of the susbtances calculated using the function $h$
#
#  (1 $\times$ 5) $\times$ (5 $\times$ A) = (1 $\times$ A) with A the number total of substances
#
# *Formated to be use in the Resilio API with the corresponding Ecoinvent elementary flow*

# %% [markdown]
# ### 1. Function g
#
# Input :
# - total CPU mass [mg] $w$ : (1 $\times$ 1)
# - percentages of the total mass of the CPU for each high level component [%], $\vec \beta$ : (1 $\times$ 5),
#
# Output :
# - mass of each of the high level components [mg], $\vec c$ : (1 $\times$ 5)
#
# $g(w, \vec \beta) = \vec c = \vec \beta \times \vec w  <=> c_i = \beta_i \times w_i $  with i = 1, 2, 3, 4, 5

# %%
def g(w, beta):
    """Calculate the mass of each high-level component."""
    c = np.zeros(5)
    for i in range(0, 4):
        c[i] = beta[i] * w
    return c

# %% [markdown]
# ### 2. Function h
#
# Input :
# - mass of each of the high level components [mg], $\vec c$ : (1 $\times$ 5)
# - percentage of mass of each substance in each high level component [%], $\vec \gamma$ : (5 $\times$ A), A is the number of substances
#
# Output :
# - mass of each of the substances [mg], $\vec m$ : (1 $\times$ A), A is the number of substances
#
# $h(\vec c, \vec \gamma) = \vec m = \vec c \times \vec \gamma$

# %%
def h(c_vec, gamma_vec):
    """Calculate the mass of each of the substances."""
    return c_vec @ gamma_vec

# %% [markdown]
# ### Modelisation

# %%
def get_beta(dfs_clean):
    """Get beta percentages from high_level_mass_matrix function."""
    beta_results = high_level_mass_matrix(dfs_clean)
    beta = {}
    for socket in beta_results:
        # Extract the percentage values directly from the DataFrame
        beta[socket] = beta_results[socket]['Percentage'].values.flatten()
    return beta


def get_gamma(dfs_clean):
    """Get gamma percentages from substance_mass_matrices function."""
    gamma_results = substance_mass_matrices(dfs_clean)
    gamma = {}
    for socket in gamma_results:
        gamma[socket] = {
            'matrix': gamma_results[socket]['Percentage'].to_numpy(),
            'substances': gamma_results[socket]['Percentage'].columns.tolist()
        }
    return gamma

# %%
def model(total_cpu_mass, dfs_clean, socket_type='LGA'):
    """
    Calculate the mass of each substance using the model, grouped by high-level material.

    Parameters:
    - total_cpu_mass: Total CPU mass in mg (scalar).
    - dfs_clean: List of DataFrames containing the data.
    - socket_type: Socket type (default is 'LGA').

    Returns:
    - DataFrame with columns: 'High Level', 'Substance', 'Mass [mg]'
    """
    # Get beta and gamma
    beta = get_beta(dfs_clean)[socket_type]
    gamma_data = get_gamma(dfs_clean)[socket_type]
    substances = gamma_data['substances']
    gamma_matrix = gamma_data['matrix']  # Shape: (n_high_level, n_substances)

    # Calculate c_vec (mass of each high-level component)
    c_vec = g(total_cpu_mass, beta)  # Shape: (n_high_level,)

    # Calculate substance masses per high-level component
    substance_masses_per_high_level = np.outer(c_vec, gamma_matrix)  # Shape: (n_high_level, n_substances)

    # Flatten and create result DataFrame
    rows = []
    high_level_materials = pd.concat(dfs_clean)['High Level Material'].unique()[:len(c_vec)]  # Match order with beta

    for i, material in enumerate(high_level_materials):
        for j, sub in enumerate(substances):
            mass = substance_masses_per_high_level[i, j]
            rows.append({
                'High Level': material,
                'Substance': sub,
                'Mass [mg]': mass
            })

    result_df = pd.DataFrame(rows)
    return result_df

# %%
pd.set_option('display.max_rows', 500)
#surface = 4256  # Surface in mm²
total_cpu_mass = 2800  # Total CPU mass in mg

# Calculate substance masses
substance_masses_df = model(total_cpu_mass, dfs_clean, socket_type='LGA')
display(substance_masses_df)
# Out:
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Percentage': percentage_matrix.fillna(0),
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Std Dev': std_dev_matrix.fillna(0)
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Percentage': percentage_matrix.fillna(0),
# C:\Users\Arthur Resilio\AppData\Local\Temp\ipykernel_23564\2948970603.py:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   'Std Dev': std_dev_matrix.fillna(0)
#         High Level                                   Substance   Mass [mg]
# 0              die                                     silicon  447.243415
# 1              die                                        gold    0.000000
# 2              die                              silicondioxide    0.000000
# 3              die                              silicone resin    0.000000
# 4              die                                      nickel    4.386781
# 5              die                                    antimony    0.000000
# 6              die                                         tin    0.350942
# 7              die                                        zinc    0.000000
# 8              die                                      copper   95.750976
# 9              die                                carbon black    0.000000
# 10             die                                     oxirane    0.000000
# 11             die                           dimethyl siloxane    0.000000
# 12             die                                    silicone    0.000000
# 13             die                               dicyandiamide    0.000000
# 14             die                                 epoxy resin    1.016048
# 15             die                         phthalocyanine blue    0.000000
# 16             die                            amorphous silica    0.000000
# 17             die                               miscellaneous    0.000000
# 18             die                  magnesiumsilicate hydrated    0.000000
# 19             die                               bariumsulfate    0.000000
# 20             die                                 cured resin    0.000000
# 21             die                 bismaleimide triazine resin    0.000000
# 22             die                          aluminiumhydroxide    0.000000
# 23             die                                 glass fibre    0.000000
# 24             die                                  phosphorus    0.000000
# 25             die                                         NaN    0.000000
# 26             die                                      cobalt    0.003070
# 27             die                                titandioxide    0.000000
# 28             die                 dimer acid diglycidyl ester    0.000000
# 29             die                                      silver    0.014623
# 30             die                     polytetrafluoroethylene    0.000000
# 31             die                                  molybdenum    0.000000
# 32             die                                    tungsten    0.026092
# 33             die                                calciumoxide    0.000000
# 34             die                              magnesiumoxide    0.000000
# 35             die                               chromiumoxide    0.000000
# 36             die                                     alumina    0.000000
# 37             die                             silicon nitride    0.178295
# 38             die                               silicon oxide    3.489911
# 39             die                           lead-borate glass    0.000000
# 40             die                                 fiber glass    0.000000
# 41             die                        bismaleimide polymer    0.000000
# 42             die                                    triazine    0.000000
# 43             die                         thermosetting resin    0.000000
# 44             die                         aluminium hydroxide    0.000000
# 45             die                             calcium sulfate    0.000000
# 46             die                              zinc hydroxide    0.000000
# 47             die                              barium sulfate    0.000000
# 48             die                bisphenol f type epoxy resin    0.000000
# 49             die                  polymerized biphenyl resin    0.000000
# 50             die       talc containing no asbestiform fibers    0.000000
# 51             die                methoxymethylethoxy propanol    0.000000
# 52             die                                   palladium    0.000000
# 53             die                              epon resin 828    0.000000
# 54             die                  silica vitreous 60676-86-0    0.000000
# 55             die               silicon dioxide cas 7631-86-9    0.000000
# 56             die           sumitomo-molding-epoxy resin a-ip    0.000000
# 57             die            sumitomo-molding-phenol resin-ip    0.000000
# 58             die                                   aluminium    0.361575
# 59             die                                    titanium    0.203907
# 60             die                                   polyimide    0.570952
# 61             die                              aluminum oxide    0.000000
# 62             die                             silicon dioxide    7.982579
# 63             die                               calcium oxide    0.000000
# 64             die                             magnesium oxide    0.000000
# 65             die                              titanium oxide    0.000000
# 66             die                              chromium oxide    0.000000
# 67             die                                       boron    0.000000
# 68             die                 phenol-formaldehyde polymer    1.016048
# 69             die                                      filler    0.000000
# 70             die                                   additives    0.000000
# 71             die                                        iron    0.000000
# 72             die                                    chromium    0.000000
# 73             die                                   manganese    0.000000
# 74             die                                      carbon    0.000000
# 75             die                                      sulfur    0.000000
# 76             die          bisphenol a diglycidyl ether resin    0.000000
# 77             die                                  zinc oxide    0.000000
# 78             die           3-glycidoxypropyltrimethoxysilane    0.000000
# 79             die            methyl methacrylate crosspolymer    0.000000
# 80             die                                    tantalum    0.043868
# 81             die                                 glass fiber    0.000000
# 82             die                                  bismethane    0.000000
# 83             die         phenolic polymer resin, epikote 155    0.000000
# 84             die                       other inoranic filler    0.000000
# 85             die            proprietary material-cured resin    0.000000
# 86             die                                      talc4)    0.000000
# 87             die                  copper phthalocyanine bule    0.000000
# 88             die                   other aluminium compounds    0.000000
# 89             die              other miscellaneous substances    0.000000
# 90             die                                          cu    0.000000
# 91             die           silica, vitreous [ fused silica ]    0.000000
# 92             die     proprietary material-other epoxy resins    0.000000
# 93             die  proprietary material-other phenolic resins    0.000000
# 94             die                             metal hydroxide    0.000000
# 95             die                          1,6-bisnaphthalene    0.000000
# 96             die              bisphenol f liquid epoxy resin    0.000000
# 97             die              bisphenol a liquid epoxy resin    0.000000
# 98             die                         amine type hardener    0.000000
# 99             die                           bismuth compounds    0.000000
# 100     connection                                     silicon   24.192524
# 101     connection                                        gold    0.000000
# 102     connection                              silicondioxide    0.000000
# 103     connection                              silicone resin    0.000000
# 104     connection                                      nickel    0.237292
# 105     connection                                    antimony    0.000000
# 106     connection                                         tin    0.018983
# 107     connection                                        zinc    0.000000
# 108     connection                                      copper    5.179412
# 109     connection                                carbon black    0.000000
# 110     connection                                     oxirane    0.000000
# 111     connection                           dimethyl siloxane    0.000000
# 112     connection                                    silicone    0.000000
# 113     connection                               dicyandiamide    0.000000
# 114     connection                                 epoxy resin    0.054961
# 115     connection                         phthalocyanine blue    0.000000
# 116     connection                            amorphous silica    0.000000
# 117     connection                               miscellaneous    0.000000
# 118     connection                  magnesiumsilicate hydrated    0.000000
# 119     connection                               bariumsulfate    0.000000
# 120     connection                                 cured resin    0.000000
# 121     connection                 bismaleimide triazine resin    0.000000
# 122     connection                          aluminiumhydroxide    0.000000
# 123     connection                                 glass fibre    0.000000
# 124     connection                                  phosphorus    0.000000
# 125     connection                                         NaN    0.000000
# 126     connection                                      cobalt    0.000166
# 127     connection                                titandioxide    0.000000
# 128     connection                 dimer acid diglycidyl ester    0.000000
# 129     connection                                      silver    0.000791
# 130     connection                     polytetrafluoroethylene    0.000000
# 131     connection                                  molybdenum    0.000000
# 132     connection                                    tungsten    0.001411
# 133     connection                                calciumoxide    0.000000
# 134     connection                              magnesiumoxide    0.000000
# 135     connection                               chromiumoxide    0.000000
# 136     connection                                     alumina    0.000000
# 137     connection                             silicon nitride    0.009644
# 138     connection                               silicon oxide    0.188778
# 139     connection                           lead-borate glass    0.000000
# 140     connection                                 fiber glass    0.000000
# 141     connection                        bismaleimide polymer    0.000000
# 142     connection                                    triazine    0.000000
# 143     connection                         thermosetting resin    0.000000
# 144     connection                         aluminium hydroxide    0.000000
# 145     connection                             calcium sulfate    0.000000
# 146     connection                              zinc hydroxide    0.000000
# 147     connection                              barium sulfate    0.000000
# 148     connection                bisphenol f type epoxy resin    0.000000
# 149     connection                  polymerized biphenyl resin    0.000000
# 150     connection       talc containing no asbestiform fibers    0.000000
# 151     connection                methoxymethylethoxy propanol    0.000000
# 152     connection                                   palladium    0.000000
# 153     connection                              epon resin 828    0.000000
# 154     connection                  silica vitreous 60676-86-0    0.000000
# 155     connection               silicon dioxide cas 7631-86-9    0.000000
# 156     connection           sumitomo-molding-epoxy resin a-ip    0.000000
# 157     connection            sumitomo-molding-phenol resin-ip    0.000000
# 158     connection                                   aluminium    0.019558
# 159     connection                                    titanium    0.011030
# 160     connection                                   polyimide    0.030884
# 161     connection                              aluminum oxide    0.000000
# 162     connection                             silicon dioxide    0.431798
# 163     connection                               calcium oxide    0.000000
# 164     connection                             magnesium oxide    0.000000
# 165     connection                              titanium oxide    0.000000
# 166     connection                              chromium oxide    0.000000
# 167     connection                                       boron    0.000000
# 168     connection                 phenol-formaldehyde polymer    0.054961
# 169     connection                                      filler    0.000000
# 170     connection                                   additives    0.000000
# 171     connection                                        iron    0.000000
# 172     connection                                    chromium    0.000000
# 173     connection                                   manganese    0.000000
# 174     connection                                      carbon    0.000000
# 175     connection                                      sulfur    0.000000
# 176     connection          bisphenol a diglycidyl ether resin    0.000000
# 177     connection                                  zinc oxide    0.000000
# 178     connection           3-glycidoxypropyltrimethoxysilane    0.000000
# 179     connection            methyl methacrylate crosspolymer    0.000000
# 180     connection                                    tantalum    0.002373
# 181     connection                                 glass fiber    0.000000
# 182     connection                                  bismethane    0.000000
# 183     connection         phenolic polymer resin, epikote 155    0.000000
# 184     connection                       other inoranic filler    0.000000
# 185     connection            proprietary material-cured resin    0.000000
# 186     connection                                      talc4)    0.000000
# 187     connection                  copper phthalocyanine bule    0.000000
# 188     connection                   other aluminium compounds    0.000000
# 189     connection              other miscellaneous substances    0.000000
# 190     connection                                          cu    0.000000
# 191     connection           silica, vitreous [ fused silica ]    0.000000
# 192     connection     proprietary material-other epoxy resins    0.000000
# 193     connection  proprietary material-other phenolic resins    0.000000
# 194     connection                             metal hydroxide    0.000000
# 195     connection                          1,6-bisnaphthalene    0.000000
# 196     connection              bisphenol f liquid epoxy resin    0.000000
# 197     connection              bisphenol a liquid epoxy resin    0.000000
# 198     connection                         amine type hardener    0.000000
# 199     connection                           bismuth compounds    0.000000
# 200  encapsulation                                     silicon  878.976730
# 201  encapsulation                                        gold    0.000000
# 202  encapsulation                              silicondioxide    0.000000
# 203  encapsulation                              silicone resin    0.000000
# 204  encapsulation                                      nickel    8.621431
# 205  encapsulation                                    antimony    0.000000
# 206  encapsulation                                         tin    0.689714
# 207  encapsulation                                        zinc    0.000000
# 208  encapsulation                                      copper  188.181373
# 209  encapsulation                                carbon black    0.000000
# 210  encapsulation                                     oxirane    0.000000
# 211  encapsulation                           dimethyl siloxane    0.000000
# 212  encapsulation                                    silicone    0.000000
# 213  encapsulation                               dicyandiamide    0.000000
# 214  encapsulation                                 epoxy resin    1.996861
# 215  encapsulation                         phthalocyanine blue    0.000000
# 216  encapsulation                            amorphous silica    0.000000
# 217  encapsulation                               miscellaneous    0.000000
# 218  encapsulation                  magnesiumsilicate hydrated    0.000000
# 219  encapsulation                               bariumsulfate    0.000000
# 220  encapsulation                                 cured resin    0.000000
# 221  encapsulation                 bismaleimide triazine resin    0.000000
# 222  encapsulation                          aluminiumhydroxide    0.000000
# 223  encapsulation                                 glass fibre    0.000000
# 224  encapsulation                                  phosphorus    0.000000
# 225  encapsulation                                         NaN    0.000000
# 226  encapsulation                                      cobalt    0.006033
# 227  encapsulation                                titandioxide    0.000000
# 228  encapsulation                 dimer acid diglycidyl ester    0.000000
# 229  encapsulation                                      silver    0.028738
# 230  encapsulation                     polytetrafluoroethylene    0.000000
# 231  encapsulation                                  molybdenum    0.000000
# 232  encapsulation                                    tungsten    0.051279
# 233  encapsulation                                calciumoxide    0.000000
# 234  encapsulation                              magnesiumoxide    0.000000
# 235  encapsulation                               chromiumoxide    0.000000
# 236  encapsulation                                     alumina    0.000000
# 237  encapsulation                             silicon nitride    0.350407
# 238  encapsulation                               silicon oxide    6.858793
# 239  encapsulation                           lead-borate glass    0.000000
# 240  encapsulation                                 fiber glass    0.000000
# 241  encapsulation                        bismaleimide polymer    0.000000
# 242  encapsulation                                    triazine    0.000000
# 243  encapsulation                         thermosetting resin    0.000000
# 244  encapsulation                         aluminium hydroxide    0.000000
# 245  encapsulation                             calcium sulfate    0.000000
# 246  encapsulation                              zinc hydroxide    0.000000
# 247  encapsulation                              barium sulfate    0.000000
# 248  encapsulation                bisphenol f type epoxy resin    0.000000
# 249  encapsulation                  polymerized biphenyl resin    0.000000
# 250  encapsulation       talc containing no asbestiform fibers    0.000000
# 251  encapsulation                methoxymethylethoxy propanol    0.000000
# 252  encapsulation                                   palladium    0.000000
# 253  encapsulation                              epon resin 828    0.000000
# 254  encapsulation                  silica vitreous 60676-86-0    0.000000
# 255  encapsulation               silicon dioxide cas 7631-86-9    0.000000
# 256  encapsulation           sumitomo-molding-epoxy resin a-ip    0.000000
# 257  encapsulation            sumitomo-molding-phenol resin-ip    0.000000
# 258  encapsulation                                   aluminium    0.710610
# 259  encapsulation                                    titanium    0.400743
# 260  encapsulation                                   polyimide    1.122103
# 261  encapsulation                              aluminum oxide    0.000000
# 262  encapsulation                             silicon dioxide   15.688328
# 263  encapsulation                               calcium oxide    0.000000
# 264  encapsulation                             magnesium oxide    0.000000
# 265  encapsulation                              titanium oxide    0.000000
# 266  encapsulation                              chromium oxide    0.000000
# 267  encapsulation                                       boron    0.000000
# 268  encapsulation                 phenol-formaldehyde polymer    1.996861
# 269  encapsulation                                      filler    0.000000
# 270  encapsulation                                   additives    0.000000
# 271  encapsulation                                        iron    0.000000
# 272  encapsulation                                    chromium    0.000000
# 273  encapsulation                                   manganese    0.000000
# 274  encapsulation                                      carbon    0.000000
# 275  encapsulation                                      sulfur    0.000000
# 276  encapsulation          bisphenol a diglycidyl ether resin    0.000000
# 277  encapsulation                                  zinc oxide    0.000000
# 278  encapsulation           3-glycidoxypropyltrimethoxysilane    0.000000
# 279  encapsulation            methyl methacrylate crosspolymer    0.000000
# 280  encapsulation                                    tantalum    0.086214
# 281  encapsulation                                 glass fiber    0.000000
# 282  encapsulation                                  bismethane    0.000000
# 283  encapsulation         phenolic polymer resin, epikote 155    0.000000
# 284  encapsulation                       other inoranic filler    0.000000
# 285  encapsulation            proprietary material-cured resin    0.000000
# 286  encapsulation                                      talc4)    0.000000
# 287  encapsulation                  copper phthalocyanine bule    0.000000
# 288  encapsulation                   other aluminium compounds    0.000000
# 289  encapsulation              other miscellaneous substances    0.000000
# 290  encapsulation                                          cu    0.000000
# 291  encapsulation           silica, vitreous [ fused silica ]    0.000000
# 292  encapsulation     proprietary material-other epoxy resins    0.000000
# 293  encapsulation  proprietary material-other phenolic resins    0.000000
# 294  encapsulation                             metal hydroxide    0.000000
# 295  encapsulation                          1,6-bisnaphthalene    0.000000
# 296  encapsulation              bisphenol f liquid epoxy resin    0.000000
# 297  encapsulation              bisphenol a liquid epoxy resin    0.000000
# 298  encapsulation                         amine type hardener    0.000000
# 299  encapsulation                           bismuth compounds    0.000000
# 300        carrier                                     silicon  820.910724
# 301        carrier                                        gold    0.000000
# 302        carrier                              silicondioxide    0.000000
# 303        carrier                              silicone resin    0.000000
# 304        carrier                                      nickel    8.051891
# 305        carrier                                    antimony    0.000000
# 306        carrier                                         tin    0.644151
# 307        carrier                                        zinc    0.000000
# 308        carrier                                      copper  175.749940
# 309        carrier                                carbon black    0.000000
# 310        carrier                                     oxirane    0.000000
# 311        carrier                           dimethyl siloxane    0.000000
# 312        carrier                                    silicone    0.000000
# 313        carrier                               dicyandiamide    0.000000
# 314        carrier                                 epoxy resin    1.864946
# 315        carrier                         phthalocyanine blue    0.000000
# 316        carrier                            amorphous silica    0.000000
# 317        carrier                               miscellaneous    0.000000
# 318        carrier                  magnesiumsilicate hydrated    0.000000
# 319        carrier                               bariumsulfate    0.000000
# 320        carrier                                 cured resin    0.000000
# 321        carrier                 bismaleimide triazine resin    0.000000
# 322        carrier                          aluminiumhydroxide    0.000000
# 323        carrier                                 glass fibre    0.000000
# 324        carrier                                  phosphorus    0.000000
# 325        carrier                                         NaN    0.000000
# 326        carrier                                      cobalt    0.005634
# 327        carrier                                titandioxide    0.000000
# 328        carrier                 dimer acid diglycidyl ester    0.000000
# 329        carrier                                      silver    0.026840
# 330        carrier                     polytetrafluoroethylene    0.000000
# 331        carrier                                  molybdenum    0.000000
# 332        carrier                                    tungsten    0.047891
# 333        carrier                                calciumoxide    0.000000
# 334        carrier                              magnesiumoxide    0.000000
# 335        carrier                               chromiumoxide    0.000000
# 336        carrier                                     alumina    0.000000
# 337        carrier                             silicon nitride    0.327259
# 338        carrier                               silicon oxide    6.405695
# 339        carrier                           lead-borate glass    0.000000
# 340        carrier                                 fiber glass    0.000000
# 341        carrier                        bismaleimide polymer    0.000000
# 342        carrier                                    triazine    0.000000
# 343        carrier                         thermosetting resin    0.000000
# 344        carrier                         aluminium hydroxide    0.000000
# 345        carrier                             calcium sulfate    0.000000
# 346        carrier                              zinc hydroxide    0.000000
# 347        carrier                              barium sulfate    0.000000
# 348        carrier                bisphenol f type epoxy resin    0.000000
# 349        carrier                  polymerized biphenyl resin    0.000000
# 350        carrier       talc containing no asbestiform fibers    0.000000
# 351        carrier                methoxymethylethoxy propanol    0.000000
# 352        carrier                                   palladium    0.000000
# 353        carrier                              epon resin 828    0.000000
# 354        carrier                  silica vitreous 60676-86-0    0.000000
# 355        carrier               silicon dioxide cas 7631-86-9    0.000000
# 356        carrier           sumitomo-molding-epoxy resin a-ip    0.000000
# 357        carrier            sumitomo-molding-phenol resin-ip    0.000000
# 358        carrier                                   aluminium    0.663667
# 359        carrier                                    titanium    0.374270
# 360        carrier                                   polyimide    1.047976
# 361        carrier                              aluminum oxide    0.000000
# 362        carrier                             silicon dioxide   14.651943
# 363        carrier                               calcium oxide    0.000000
# 364        carrier                             magnesium oxide    0.000000
# 365        carrier                              titanium oxide    0.000000
# 366        carrier                              chromium oxide    0.000000
# 367        carrier                                       boron    0.000000
# 368        carrier                 phenol-formaldehyde polymer    1.864946
# 369        carrier                                      filler    0.000000
# 370        carrier                                   additives    0.000000
# 371        carrier                                        iron    0.000000
# 372        carrier                                    chromium    0.000000
# 373        carrier                                   manganese    0.000000
# 374        carrier                                      carbon    0.000000
# 375        carrier                                      sulfur    0.000000
# 376        carrier          bisphenol a diglycidyl ether resin    0.000000
# 377        carrier                                  zinc oxide    0.000000
# 378        carrier           3-glycidoxypropyltrimethoxysilane    0.000000
# 379        carrier            methyl methacrylate crosspolymer    0.000000
# 380        carrier                                    tantalum    0.080519
# 381        carrier                                 glass fiber    0.000000
# 382        carrier                                  bismethane    0.000000
# 383        carrier         phenolic polymer resin, epikote 155    0.000000
# 384        carrier                       other inoranic filler    0.000000
# 385        carrier            proprietary material-cured resin    0.000000
# 386        carrier                                      talc4)    0.000000
# 387        carrier                  copper phthalocyanine bule    0.000000
# 388        carrier                   other aluminium compounds    0.000000
# 389        carrier              other miscellaneous substances    0.000000
# 390        carrier                                          cu    0.000000
# 391        carrier           silica, vitreous [ fused silica ]    0.000000
# 392        carrier     proprietary material-other epoxy resins    0.000000
# 393        carrier  proprietary material-other phenolic resins    0.000000
# 394        carrier                             metal hydroxide    0.000000
# 395        carrier                          1,6-bisnaphthalene    0.000000
# 396        carrier              bisphenol f liquid epoxy resin    0.000000
# 397        carrier              bisphenol a liquid epoxy resin    0.000000
# 398        carrier                         amine type hardener    0.000000
# 399        carrier                           bismuth compounds    0.000000
# 400      finishing                                     silicon    0.000000
# 401      finishing                                        gold    0.000000
# 402      finishing                              silicondioxide    0.000000
# 403      finishing                              silicone resin    0.000000
# 404      finishing                                      nickel    0.000000
# 405      finishing                                    antimony    0.000000
# 406      finishing                                         tin    0.000000
# 407      finishing                                        zinc    0.000000
# 408      finishing                                      copper    0.000000
# 409      finishing                                carbon black    0.000000
# 410      finishing                                     oxirane    0.000000
# 411      finishing                           dimethyl siloxane    0.000000
# 412      finishing                                    silicone    0.000000
# 413      finishing                               dicyandiamide    0.000000
# 414      finishing                                 epoxy resin    0.000000
# 415      finishing                         phthalocyanine blue    0.000000
# 416      finishing                            amorphous silica    0.000000
# 417      finishing                               miscellaneous    0.000000
# 418      finishing                  magnesiumsilicate hydrated    0.000000
# 419      finishing                               bariumsulfate    0.000000
# 420      finishing                                 cured resin    0.000000
# 421      finishing                 bismaleimide triazine resin    0.000000
# 422      finishing                          aluminiumhydroxide    0.000000
# 423      finishing                                 glass fibre    0.000000
# 424      finishing                                  phosphorus    0.000000
# 425      finishing                                         NaN    0.000000
# 426      finishing                                      cobalt    0.000000
# 427      finishing                                titandioxide    0.000000
# 428      finishing                 dimer acid diglycidyl ester    0.000000
# 429      finishing                                      silver    0.000000
# 430      finishing                     polytetrafluoroethylene    0.000000
# 431      finishing                                  molybdenum    0.000000
# 432      finishing                                    tungsten    0.000000
# 433      finishing                                calciumoxide    0.000000
# 434      finishing                              magnesiumoxide    0.000000
# 435      finishing                               chromiumoxide    0.000000
# 436      finishing                                     alumina    0.000000
# 437      finishing                             silicon nitride    0.000000
# 438      finishing                               silicon oxide    0.000000
# 439      finishing                           lead-borate glass    0.000000
# 440      finishing                                 fiber glass    0.000000
# 441      finishing                        bismaleimide polymer    0.000000
# 442      finishing                                    triazine    0.000000
# 443      finishing                         thermosetting resin    0.000000
# 444      finishing                         aluminium hydroxide    0.000000
# 445      finishing                             calcium sulfate    0.000000
# 446      finishing                              zinc hydroxide    0.000000
# 447      finishing                              barium sulfate    0.000000
# 448      finishing                bisphenol f type epoxy resin    0.000000
# 449      finishing                  polymerized biphenyl resin    0.000000
# 450      finishing       talc containing no asbestiform fibers    0.000000
# 451      finishing                methoxymethylethoxy propanol    0.000000
# 452      finishing                                   palladium    0.000000
# 453      finishing                              epon resin 828    0.000000
# 454      finishing                  silica vitreous 60676-86-0    0.000000
# 455      finishing               silicon dioxide cas 7631-86-9    0.000000
# 456      finishing           sumitomo-molding-epoxy resin a-ip    0.000000
# 457      finishing            sumitomo-molding-phenol resin-ip    0.000000
# 458      finishing                                   aluminium    0.000000
# 459      finishing                                    titanium    0.000000
# 460      finishing                                   polyimide    0.000000
# 461      finishing                              aluminum oxide    0.000000
# 462      finishing                             silicon dioxide    0.000000
# 463      finishing                               calcium oxide    0.000000
# 464      finishing                             magnesium oxide    0.000000
# 465      finishing                              titanium oxide    0.000000
# 466      finishing                              chromium oxide    0.000000
# 467      finishing                                       boron    0.000000
# 468      finishing                 phenol-formaldehyde polymer    0.000000
# 469      finishing                                      filler    0.000000
# 470      finishing                                   additives    0.000000
# 471      finishing                                        iron    0.000000
# 472      finishing                                    chromium    0.000000
# 473      finishing                                   manganese    0.000000
# 474      finishing                                      carbon    0.000000
# 475      finishing                                      sulfur    0.000000
# 476      finishing          bisphenol a diglycidyl ether resin    0.000000
# 477      finishing                                  zinc oxide    0.000000
# 478      finishing           3-glycidoxypropyltrimethoxysilane    0.000000
# 479      finishing            methyl methacrylate crosspolymer    0.000000
# 480      finishing                                    tantalum    0.000000
# 481      finishing                                 glass fiber    0.000000
# 482      finishing                                  bismethane    0.000000
# 483      finishing         phenolic polymer resin, epikote 155    0.000000
# 484      finishing                       other inoranic filler    0.000000
# 485      finishing            proprietary material-cured resin    0.000000
# 486      finishing                                      talc4)    0.000000
# 487      finishing                  copper phthalocyanine bule    0.000000
# 488      finishing                   other aluminium compounds    0.000000
# 489      finishing              other miscellaneous substances    0.000000
# 490      finishing                                          cu    0.000000
# 491      finishing           silica, vitreous [ fused silica ]    0.000000
# 492      finishing     proprietary material-other epoxy resins    0.000000
# 493      finishing  proprietary material-other phenolic resins    0.000000
# 494      finishing                             metal hydroxide    0.000000
# 495      finishing                          1,6-bisnaphthalene    0.000000
# 496      finishing              bisphenol f liquid epoxy resin    0.000000
# 497      finishing              bisphenol a liquid epoxy resin    0.000000
# 498      finishing                         amine type hardener    0.000000
# 499      finishing                           bismuth compounds    0.000000

# %%
DIRECT_MAPPING = {
        "gold": "Gold()",
        "nickel": "Nickel()",
        "alumina": "AluminiumOxide()",
        "aluminium hydroxide": "AluminiumHydroxide()",
        "aluminiumhydroxide": "AluminiumHydroxide()",
        "aluminum oxide": "AluminiumOxide()",
        "amorphous silica": "Silica()",
        "barium sulfate": "BariumSulfide()",
        "bismaleimide polymer": "EpoxyResin()",
        "bismethane": "Pentane()",
        "bisphenol f type epoxy resin": "BisphenolAEpoxy()",
        "bisphenol a diglycidyl ether resin": "BisphenolAEpoxy()",
        "boron": "BoronCarbide()",
        "calcium oxide": "HydratedLime()",
        "calcium sulfate": "HydratedLime()",
        "calciumoxide": "HydratedLime()",
        "chromium oxide": "Chromium()",
        "chromiumoxide": "Chromium()",
        "copper": "Copper()",
        "copper phthalocyanine bule": "Copper()",
        "cu": "Copper()",
        "dimethyl siloxane": "SiliconeTetrachloride()",
        "fiber glass": "GlassFibre()",
        "glass fiber": "GlassFibre()",
        "glass fibre": "GlassFibre()",
        "magnesium oxide": "MagnesiumOxide()",
        "magnesiumoxide": "MagnesiumOxide()",
        "methoxymethylethoxy propanol": "MethoxyPropanol()",
        "molybdenum": "Molybdenum()",
        "other aluminium compounds": "AluminiumIngot()",
        "other inoranic filler": "InorganicChemicals()",
        "phenolic polymer resin, epikote 155": "PhenolicResin()",
        "phosphorus": "PhosphorousChloride()",
        "polymerized biphenyl resin": "EpoxyResin()",
        "proprietary material-cured resin": "EpoxyResin()",
        "silicon dioxide": "Silicone()",
        "talc containing no asbestiform fibers": "MagnesiumOxide()",
        "talc4)": "MagnesiumOxide()",
        "thermosetting resin": "EpoxyResin()",
        "titandioxide": "TitaniumDioxide()",
        "titanium oxide": "TitaniumDioxide()",
        "triazine": "Triazine()",
        "tungsten": "Tungsten()",
        "zinc hydroxide": "ZincOxide()",
        "zinc": "ZincOxide()",
        "bismaleimide triazine resin": "Triazine()",
        "silver": "Silver()",
        "tin": "Tin()",
        "1,6-bisnaphthalene": "EpoxyResin()",
        "3-glycidoxypropyltrimethoxysilane": "EpoxyResin()",
        "additives": "PhthalicAnhydride()",
        "amine type hardener": "Piperidine()",
        "bisphenol a liquid epoxy resin": "BisphenolAEpoxy()",
        "bisphenol f liquid epoxy resin": "BisphenolAEpoxy()",
        "carbon black": "CarbonBlack()",
        "silicondioxide": "Silica()",
        "silicone resin": "Silicone()",
        "silicone": "Silicone()",
        "carbon": "CarbonBlack()",
        "chromium": "Chromium()",
        "iron": "PigIron()",
        "manganese": "Manganese()",
        "methyl methacrylate crosspolymer": "MethylMethacrylate()",
        "silicon": "Silicone()",
        "sulfur": "Sulfur()",
        "dimer acid diglycidyl ester": "Adhesive()",
        "epon resin 828": "EpoxyResin()",
        "epoxy resin": "EpoxyResin()",
        "metal hydroxide": "AluminiumHydroxide()",
        "polytetrafluoroethylene": "PolytetraFluoroEthylene()",
        "proprietary material-other epoxy resins": "EpoxyResin()",
        "proprietary material-other phenolic resins": "PhenolicResin()",
        "silica vitreous 60676-86-0": "Silica()",
        "silica, vitreous [ fused silica ]": "Silica()",
        "silicon dioxide cas 7631-86-9": "Silicone()",
        "silicondioxide": "Silicone()",
        "sumitomo-molding-epoxy resin a-ip": "EpoxyResin()",
        "sumitomo-molding-phenol resin-ip": "EpoxyResin()",
        "cobalt": "Cobalt()",
        "dicyandiamide": "Nitrile()",
        "oxirane": "EthyleneOxide()",
        "filler": "CalciumCarbonate()",
        "palladium": "Palladium()",
        "silicone tetrachloride": "SiliconeTetrachloride()",
    }

# %%
def element_masses_to_api_text(substance_masses_df, DM=DIRECT_MAPPING):
    """
    Convert substance masses DataFrame to a formatted text message for API usage.
    Args:
        substance_masses_df: DataFrame with columns ['High Level', 'Substance', 'Mass [mg]'].
        DM: Dictionary for direct mapping of substances to terminal classes.
    Returns:
        Formatted string for API usage.
    """
    result = "SUBSTANCES: list[Exchange] = [\n"
    for _, row in substance_masses_df.iterrows():
        high_level = row['High Level']
        element = row['Substance']
        
        # Skip if High Level is 'die'
        if high_level == 'die':
            continue
            
        # Skip if element is not a string
        if not isinstance(element, str):
            continue
            
        mass = row['Mass [mg]']
        terminal_class = DM.get(element.lower())
        if terminal_class:
            mass_str = f"{mass:.15g}"
            result += f"    Exchange({mass_str} * 1e-6, {terminal_class}),\n"
    result += "]\n"
    return result

# %%
api_text = element_masses_to_api_text(substance_masses_df)
print(api_text)
# Out:
# SUBSTANCES: list[Exchange] = [
#     Exchange(24.1925239970736 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Gold()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0.237292027361975 * 1e-6, Nickel()),
#     Exchange(0.018983362188958 * 1e-6, Tin()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(5.17941172604458 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, EthyleneOxide()),
#     Exchange(0 * 1e-6, SiliconeTetrachloride()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Nitrile()),
#     Exchange(0.0549606176400331 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, PhosphorousChloride()),
#     Exchange(0.000166044162054481 * 1e-6, Cobalt()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Adhesive()),
#     Exchange(0.000790973424539918 * 1e-6, Silver()),
#     Exchange(0 * 1e-6, PolytetraFluoroEthylene()),
#     Exchange(0 * 1e-6, Molybdenum()),
#     Exchange(0.00141137537746309 * 1e-6, Tungsten()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(0 * 1e-6, BariumSulfide()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, MethoxyPropanol()),
#     Exchange(0 * 1e-6, Palladium()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(0.431797843422677 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, BoronCarbide()),
#     Exchange(0 * 1e-6, CalciumCarbonate()),
#     Exchange(0 * 1e-6, PhthalicAnhydride()),
#     Exchange(0 * 1e-6, PigIron()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, Manganese()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, Sulfur()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MethylMethacrylate()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, Pentane()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, InorganicChemicals()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, AluminiumIngot()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, Piperidine()),
#     Exchange(878.976730146977 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Gold()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(8.62143074967317 * 1e-6, Nickel()),
#     Exchange(0.689714459973854 * 1e-6, Tin()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(188.181373038806 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, EthyleneOxide()),
#     Exchange(0 * 1e-6, SiliconeTetrachloride()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Nitrile()),
#     Exchange(1.99686084783623 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, PhosphorousChloride()),
#     Exchange(0.00603281222911246 * 1e-6, Cobalt()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Adhesive()),
#     Exchange(0.0287381024989106 * 1e-6, Silver()),
#     Exchange(0 * 1e-6, PolytetraFluoroEthylene()),
#     Exchange(0 * 1e-6, Molybdenum()),
#     Exchange(0.0512789039474559 * 1e-6, Tungsten()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(0 * 1e-6, BariumSulfide()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, MethoxyPropanol()),
#     Exchange(0 * 1e-6, Palladium()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(15.688328201807 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, BoronCarbide()),
#     Exchange(0 * 1e-6, CalciumCarbonate()),
#     Exchange(0 * 1e-6, PhthalicAnhydride()),
#     Exchange(0 * 1e-6, PigIron()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, Manganese()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, Sulfur()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MethylMethacrylate()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, Pentane()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, InorganicChemicals()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, AluminiumIngot()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, Piperidine()),
#     Exchange(820.910723836979 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Gold()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(8.05189115306972 * 1e-6, Nickel()),
#     Exchange(0.644151292245577 * 1e-6, Tin()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(175.74993950988 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, EthyleneOxide()),
#     Exchange(0 * 1e-6, SiliconeTetrachloride()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Nitrile()),
#     Exchange(1.86494639479802 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, PhosphorousChloride()),
#     Exchange(0.00563427913836261 * 1e-6, Cobalt()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Adhesive()),
#     Exchange(0.0268396371768991 * 1e-6, Silver()),
#     Exchange(0 * 1e-6, PolytetraFluoroEthylene()),
#     Exchange(0 * 1e-6, Molybdenum()),
#     Exchange(0.0478913726760822 * 1e-6, Tungsten()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(0 * 1e-6, BariumSulfide()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, MethoxyPropanol()),
#     Exchange(0 * 1e-6, Palladium()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(14.651942899312 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, BoronCarbide()),
#     Exchange(0 * 1e-6, CalciumCarbonate()),
#     Exchange(0 * 1e-6, PhthalicAnhydride()),
#     Exchange(0 * 1e-6, PigIron()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, Manganese()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, Sulfur()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MethylMethacrylate()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, Pentane()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, InorganicChemicals()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, AluminiumIngot()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, Piperidine()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Gold()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Nickel()),
#     Exchange(0 * 1e-6, Tin()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, EthyleneOxide()),
#     Exchange(0 * 1e-6, SiliconeTetrachloride()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, Nitrile()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, PhosphorousChloride()),
#     Exchange(0 * 1e-6, Cobalt()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Adhesive()),
#     Exchange(0 * 1e-6, Silver()),
#     Exchange(0 * 1e-6, PolytetraFluoroEthylene()),
#     Exchange(0 * 1e-6, Molybdenum()),
#     Exchange(0 * 1e-6, Tungsten()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Triazine()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, ZincOxide()),
#     Exchange(0 * 1e-6, BariumSulfide()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, MethoxyPropanol()),
#     Exchange(0 * 1e-6, Palladium()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, AluminiumOxide()),
#     Exchange(0 * 1e-6, Silicone()),
#     Exchange(0 * 1e-6, HydratedLime()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, TitaniumDioxide()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, BoronCarbide()),
#     Exchange(0 * 1e-6, CalciumCarbonate()),
#     Exchange(0 * 1e-6, PhthalicAnhydride()),
#     Exchange(0 * 1e-6, PigIron()),
#     Exchange(0 * 1e-6, Chromium()),
#     Exchange(0 * 1e-6, Manganese()),
#     Exchange(0 * 1e-6, CarbonBlack()),
#     Exchange(0 * 1e-6, Sulfur()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MethylMethacrylate()),
#     Exchange(0 * 1e-6, GlassFibre()),
#     Exchange(0 * 1e-6, Pentane()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, InorganicChemicals()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, MagnesiumOxide()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, AluminiumIngot()),
#     Exchange(0 * 1e-6, Copper()),
#     Exchange(0 * 1e-6, Silica()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, PhenolicResin()),
#     Exchange(0 * 1e-6, AluminiumHydroxide()),
#     Exchange(0 * 1e-6, EpoxyResin()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, BisphenolAEpoxy()),
#     Exchange(0 * 1e-6, Piperidine()),
# ]

# %% [markdown]
# # **Error propagation in the model**

# %% [markdown]
# ### **1. Model definition**
#
# Steps of the model :
#
# - $\vec c = g(w, \vec\beta) = \vec\beta \times w → c_i = \beta_i \times w$
#
# - $m = h(\vec c, \gamma) = \vec c \times \gamma → m_j = \Sigma_i (c_i \times\gamma_{ij}) = \Sigma_i (\beta_i \times w \times \gamma_{ij})$
#
# Definition of the mass of a substance j : $m_j = w \times \Sigma_i (\vec\beta_i \times γ_{ij})$
#
# Incertainties :
#
# - $\sigma_w$ (uncertainty of total mass w) ?
# - $\sigma_{\beta_i}$ (uncertainty of each $\beta_i$)
# - $\sigma_{\gamma_{ij}}$ (uncertainty of each $\gamma_{ij}$)
#
# Assumptions : Independent variables (but $\gamma$ and $\beta$ are correlated since they both have been estimated from the same dataset)
#
# ### **2. Error propagation**
#
# The general formula for variance propagation for a function $y = f(x_1, x_2, ...)$ is :
#
# $\sigma_y^2 = \Sigma_i (\frac{∂ f}{∂ x_i})^2 \times \sigma_{x_i}^2$
#
# In our case : $m_j = f(\vec \beta, w, \gamma) = w \times \Sigma_i (\beta_i \times \gamma_{ij})$ thus,
#
# $\sigma_{m_j}^2 = (\frac{∂m_j}{∂w})² σ_w² + Σᵢ (\frac{∂m_j}{∂βᵢ})² σ_{βᵢ}² + Σᵢ (\frac{∂m_j}{∂γᵢⱼ})² σ_{γᵢⱼ}² $
#
# With :
#
# - $∂m_j/∂w = Σᵢ (βᵢ × γᵢⱼ)$
# - $∂m_j/∂βᵢ = w × γᵢⱼ$
# - $∂m_j/∂γᵢⱼ = w × βᵢ$
#
#
# **Law of variance propagation : $K_{yy} = F · K_{xx} · F^T$**
#
# With:
#
# - $K_{yy}$ = covariance matrix of outputs
# - F = Jacobian matrix of partial derivatives
# - $K_{xx}$ = covariance matrix of inputs

# %%
def propagate_error(model_output_df, total_cpu_mass, sigma_w, beta_df, gamma_df, sigma_gamma_df, cov_beta_gamma=None):
    """
    Propagates uncertainty through the model:
        m_j = w * sum_i (beta_i * gamma_ij)

    Explicitly constructs the Jacobian matrix F and the covariance matrix K_xx,
    accounting for potential correlations between beta and gamma.

    Parameters:
    - model_output_df: DataFrame from model() with columns ['High Level', 'Substance', 'Mass [mg]']
    - total_cpu_mass: scalar, total CPU mass in mg
    - sigma_w: scalar, uncertainty of total_cpu_mass
    - beta_df: DataFrame with 'Percentage' and 'Std Dev' for high-level components
    - gamma_df: DataFrame with substance fractions (n_beta x A)
    - sigma_gamma_df: DataFrame with std dev of gamma (n_beta x A)
    - cov_beta_gamma: Covariance matrix between beta and gamma (optional, default is None)

    Returns:
    - model_output_df with added columns:
        'Uncertainty [mg]', 'Rel Uncertainty [%]'
    """

    # Extract beta and sigma_beta
    beta = beta_df['Percentage'].values  # shape (n_beta,)
    sigma_beta = beta_df['Std Dev'].values  # shape (n_beta,)

    # Extract gamma and sigma_gamma
    gamma = gamma_df.values  # shape (n_beta, A)
    sigma_gamma = sigma_gamma_df.values  # shape (n_beta, A)

    # Number of substances and high-level components
    A = gamma.shape[1]
    n_beta = beta.shape[0]

    # Get unique high-level materials (must match beta order)
    high_level_materials = beta_df.index.tolist() if hasattr(beta_df, 'index') else [f"HL{i}" for i in range(n_beta)]

    # Initialize uncertainty array — now we need one per (high-level, substance) pair
    # We'll compute it per high-level material and substance
    sigma_m = np.zeros(len(model_output_df))  # shape (500,)

    # For each row in model_output_df (each (high-level, substance) pair)
    for idx, row in model_output_df.iterrows():
        high_level = row['High Level']
        substance = row['Substance']

        # Get index of high-level material
        try:
            i = high_level_materials.index(high_level)
        except ValueError:
            # If high-level not in beta, skip or set 0
            sigma_m[idx] = 0.0
            continue

        # Get index of substance
        try:
            j = gamma_df.columns.get_loc(substance)
        except KeyError:
            sigma_m[idx] = 0.0
            continue

        # Construct Jacobian matrix F for this (i, j) pair
        dmdw = beta[i] * gamma[i, j]  # ∂m_ij/∂w
        dmdbeta = np.zeros(n_beta)
        dmdbeta[i] = total_cpu_mass * gamma[i, j]  # ∂m_ij/∂β_i
        dmdgamma = np.zeros(n_beta)
        dmdgamma[i] = total_cpu_mass * beta[i]  # ∂m_ij/∂γ_ij

        # Combine into F (1 x (1 + n_beta + n_beta) row vector)
        F = np.hstack([[dmdw], dmdbeta, dmdgamma])

        # Construct covariance matrix K_xx
        # Diagonal elements for w, beta, and gamma
        diag_elements = np.hstack([[sigma_w**2], sigma_beta**2, sigma_gamma[:, j]**2])

        # Initialize K_xx as a diagonal matrix
        K_xx = np.diag(diag_elements)

        # If cov_beta_gamma is provided, update the off-diagonal elements
        if cov_beta_gamma is not None:
            # Assume cov_beta_gamma is shape (n_beta, n_beta)
            for k in range(n_beta):
                for l in range(n_beta):
                    # Update covariance between beta_k and gamma_lj
                    K_xx[1 + k, 1 + n_beta + l] = cov_beta_gamma[k, l]
                    K_xx[1 + n_beta + l, 1 + k] = cov_beta_gamma[k, l]

        # Compute variance using F * K_xx * F^T
        sigma_m_sq = F @ K_xx @ F.T
        sigma_m[idx] = np.sqrt(sigma_m_sq)

    # Add to DataFrame
    result_df = model_output_df.copy()
    result_df['Uncertainty [mg]'] = sigma_m
    result_df['Rel Uncertainty [%]'] = (sigma_m / result_df['Mass [mg]']) * 100

    return result_df

# %%
# 1. Define uncertainties
sigma_w = 1.0  # mg

# 2. Get beta and gamma data
beta_df = high_level_results["LGA"]  # has 'Percentage', 'Std Dev'
gamma_df = results['LGA']['Percentage']  # 5 x 100
sigma_gamma_df = results['LGA']['Std Dev']  # 5 x 100

# 3. Propagate error — now works with 500 rows
result_with_uncertainty = propagate_error(
    model_output_df=substance_masses_df,  # 500 rows: ['High Level', 'Substance', 'Mass [mg]']
    total_cpu_mass=2800.0,
    sigma_w=sigma_w,
    beta_df=beta_df,
    gamma_df=gamma_df,
    sigma_gamma_df=sigma_gamma_df
)

# 4. Display
print("Substance Masses with propagated uncertainty:")
display(result_with_uncertainty.head())
# Out:
# Substance Masses with propagated uncertainty:
#   High Level       Substance   Mass [mg]  Uncertainty [mg]  \
# 0        die         silicon  447.243415        246.835442
# 1        die            gold    0.000000          0.000000
# 2        die  silicondioxide    0.000000          0.000000
# 3        die  silicone resin    0.000000          0.000000
# 4        die          nickel    4.386781          8.893674
#
#    Rel Uncertainty [%]
# 0            55.190403
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4           202.738070

# %% [markdown]
# ### Since gamma and beta are estimated from the same set of material declaration sheets can take into account the correlation with covariance matrices, however due to small dataset it may exagerate the incertitudes

# %%
def propagate_error_cov(model_output_df, total_cpu_mass, sigma_w, beta_df, gamma_df, sigma_gamma_df, cov_beta=None, cov_gamma=None, cov_beta_gamma=None):
    """
    Propagates uncertainty through the model using covariance matrices.

    Computes two bounds:
    - Underestimate: assumes no correlations (diagonal covariances)
    - Overestimate: uses provided covariances (if any)

    Parameters:
    - model_output_df: DataFrame with columns ['High Level', 'Substance', 'Mass [mg]']
    - total_cpu_mass: scalar, total CPU mass in mg
    - sigma_w: scalar, uncertainty of total_cpu_mass
    - beta_df: DataFrame with 'Percentage' and 'Std Dev' for high-level components
    - gamma_df: DataFrame with substance fractions (n_beta x A)
    - sigma_gamma_df: DataFrame with std dev of gamma (n_beta x A)
    - cov_beta: Covariance matrix for beta (n_beta x n_beta) (optional)
    - cov_gamma: Covariance matrix for gamma (n_beta x n_beta) (optional)
    - cov_beta_gamma: Covariance matrix between beta and gamma (optional, n_beta x n_beta)

    Returns:
    - model_output_df with added columns:
        'Sigma [mg] (Underestimate)', 'Sigma [%] (Underestimate)',
        'Sigma [mg] (Overestimate)', 'Sigma [%] (Overestimate)'
    """

    # Extract beta and sigma_beta
    beta = beta_df['Percentage'].values  # shape (n_beta,)
    sigma_beta = beta_df['Std Dev'].values  # shape (n_beta,)

    # Extract gamma and sigma_gamma
    gamma = gamma_df.values  # shape (n_beta, A)
    sigma_gamma = sigma_gamma_df.values  # shape (n_beta, A)

    # Number of substances and high-level components
    A = gamma.shape[1]
    n_beta = beta.shape[0]

    # Get high-level material names (must match beta order)
    high_level_materials = beta_df.index.tolist() if hasattr(beta_df, 'index') else [f"HL{i}" for i in range(n_beta)]

    # Initialize uncertainty arrays
    sigma_m_under = np.zeros(len(model_output_df))
    sigma_m_over = np.zeros(len(model_output_df))

    # For each row in model_output_df
    for idx, row in model_output_df.iterrows():
        high_level = row['High Level']
        substance = row['Substance']

        # Get index of high-level material
        try:
            i = high_level_materials.index(high_level)
        except ValueError:
            sigma_m_under[idx] = 0.0
            sigma_m_over[idx] = 0.0
            continue

        # Get index of substance
        try:
            j = gamma_df.columns.get_loc(substance)
        except KeyError:
            sigma_m_under[idx] = 0.0
            sigma_m_over[idx] = 0.0
            continue

        # Construct Jacobian matrix F for this (i, j) pair
        dmdw = beta[i] * gamma[i, j]  # ∂m_ij/∂w
        dmdbeta = np.zeros(n_beta)
        dmdbeta[i] = total_cpu_mass * gamma[i, j]  # ∂m_ij/∂β_i
        dmdgamma = np.zeros(n_beta)
        dmdgamma[i] = total_cpu_mass * beta[i]  # ∂m_ij/∂γ_ij

        # Combine into F (1 x (1 + n_beta + n_beta) row vector)
        F = np.hstack([[dmdw], dmdbeta, dmdgamma])

        # ————————————————————————————————————————————————————————————————
        # Underestimate: Assume no correlations (diagonal)
        # ————————————————————————————————————————————————————————————————

        K_w = np.array([[sigma_w**2]])
        K_beta_under = np.diag(sigma_beta**2)
        K_gamma_under = np.diag(sigma_gamma[:, j]**2)
        K_beta_gamma_under = np.zeros((n_beta, n_beta))

        K_xx_under = np.block([
            [K_w, np.zeros((1, n_beta)), np.zeros((1, n_beta))],
            [np.zeros((n_beta, 1)), K_beta_under, K_beta_gamma_under],
            [np.zeros((n_beta, 1)), K_beta_gamma_under.T, K_gamma_under]
        ])

        sigma_m_sq_under = F @ K_xx_under @ F.T
        sigma_m_under[idx] = np.sqrt(sigma_m_sq_under)

        # ————————————————————————————————————————————————————————————————
        # Overestimate: Use provided covariances (if any)
        # ————————————————————————————————————————————————————————————————

        # Use provided covariances if available, else fall back to diagonal
        K_beta_over = cov_beta if cov_beta is not None else np.diag(sigma_beta**2)
        K_gamma_over = cov_gamma if cov_gamma is not None else np.diag(sigma_gamma[:, j]**2)
        K_beta_gamma_over = cov_beta_gamma if cov_beta_gamma is not None else np.zeros((n_beta, n_beta))

        K_xx_over = np.block([
            [K_w, np.zeros((1, n_beta)), np.zeros((1, n_beta))],
            [np.zeros((n_beta, 1)), K_beta_over, K_beta_gamma_over],
            [np.zeros((n_beta, 1)), K_beta_gamma_over.T, K_gamma_over]
        ])

        sigma_m_sq_over = F @ K_xx_over @ F.T
        sigma_m_over[idx] = np.sqrt(sigma_m_sq_over)

    # Add to DataFrame
    result_df = model_output_df.copy()
    result_df['Sigma [mg] (Underestimate)'] = sigma_m_under
    result_df['Sigma [%] (Underestimate)'] = (sigma_m_under / result_df['Mass [mg]']) * 100
    result_df['Sigma [mg] (Overestimate)'] = sigma_m_over
    result_df['Sigma [%] (Overestimate)'] = (sigma_m_over / result_df['Mass [mg]']) * 100

    return result_df

# %%
# Calculate covariance matrices (optional)
covariance_matrices = calculate_covariance(dfs_clean)
cov_beta = covariance_matrices["LGA"]["cov_beta"]
cov_gamma = covariance_matrices["LGA"]["cov_gamma"]
cov_beta_gamma = covariance_matrices["LGA"]["cov_beta_gamma"]

# 1. Define uncertainties
sigma_w = 1.0  # mg

# 2. Get beta and gamma data
beta_df = high_level_results["LGA"]  # has 'Percentage', 'Std Dev'
gamma_df = results['LGA']['Percentage']  # 5 x 100
sigma_gamma_df = results['LGA']['Std Dev']  # 5 x 100

# 3. Propagate error — works with 500 rows, optional covariances
result_with_uncertainty = propagate_error_cov(
    model_output_df=substance_masses_df,  # 500 rows: ['High Level', 'Substance', 'Mass [mg]']
    total_cpu_mass=2800.0,
    sigma_w=sigma_w,
    beta_df=beta_df,
    gamma_df=gamma_df,
    sigma_gamma_df=sigma_gamma_df,
    cov_beta=cov_beta,
    cov_gamma=cov_gamma,
    cov_beta_gamma=cov_beta_gamma
)

# 4. Display
print("Substance Masses with propagated uncertainty (under/over estimate):")
display(result_with_uncertainty.head(10))
# Out:
# Substance Masses with propagated uncertainty (under/over estimate):
#   High Level       Substance   Mass [mg]  Sigma [mg] (Underestimate)  \
# 0        die         silicon  447.243415                  246.835442
# 1        die            gold    0.000000                    0.000000
# 2        die  silicondioxide    0.000000                    0.000000
# 3        die  silicone resin    0.000000                    0.000000
# 4        die          nickel    4.386781                    8.893674
# 5        die        antimony    0.000000                    0.000000
# 6        die             tin    0.350942                    0.711494
# 7        die            zinc    0.000000                    0.000000
# 8        die          copper   95.750976                  194.010146
# 9        die    carbon black    0.000000                    0.000000
#
#    Sigma [%] (Underestimate)  Sigma [mg] (Overestimate)  \
# 0                  55.190403                 168.918515
# 1                        NaN                  30.792211
# 2                        NaN                  30.792211
# 3                        NaN                  30.792211
# 4                 202.738070                  30.837402
# 5                        NaN                  30.792211
# 6                 202.738070                  30.792659
# 7                        NaN                  30.792211
# 8                 202.619497                  47.061756
# 9                        NaN                  30.792211
#
#    Sigma [%] (Overestimate)
# 0                 37.768810
# 1                       inf
# 2                       inf
# 3                       inf
# 4                702.962011
# 5                       inf
# 6               8774.275894
# 7                       inf
# 8                 49.150158
# 9                       inf

# %% [markdown]
# # **Correction of the model**
#
# Experiences :
#
# - 7 Intel CPU
# - 1 AMD CPU
# - 2 Intel metal lid
#
# Input :
# - Sample mass
#
# Output :
# - 10 substances analysis
